# %%
#To register MainEnvRL with local copy of Gym
"""
from gym.envs.registration import register
 
register(
    id='MainEnvRL-v0',
    #entry_point='balance_bot.envs:BalancebotEnv',
    entry_point='MainEnv_RL.envs:MainEnvRL',
)
"""

# %%
#https://github.com/ZhizhenQin/BalancingBot/blob/master/balance-bot/balance_bot/balancebot_task.py

import tensorflow as tf
import tensorflow.contrib.layers as layers
import gym
from baselines import deepq
#import balance_bot
import MainEnv_RL

def callback(lcl, glb):
    # stop training if reward exceeds 199
    is_solved = lcl['t'] > 100 and sum(lcl['episode_rewards'][-101:-1]) / 100 >= 199
    return is_solved

def main():
    # create the environment
    env = gym.make("MainEnvRL-v0") # <-- this we need to create

    # create the learning agent
    #model = mlp([16, 16])  q_func=model,

    # train the agent on the environment
    act = deepq.learn(
        env, network= 'mlp',  lr=1e-3,
        total_timesteps=200000, buffer_size=50000, exploration_fraction=0.1,
        exploration_final_eps=0.02, print_freq=10, callback=callback
    )
    
    
    # save trained model
    act.save("balance.pkl")

if __name__ == '__main__':
    main()
# Out:
# /home/scott/.local/lib/python3.6/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /home/scott/.local/lib/python3.6/site-packages/gym/logger.py:30: UserWarning: WARN: Environment '<class 'MainEnv_RL.envs.mainenv_rl.MainEnvRL'>' has deprecated methods '_step' and '_reset' rather than 'step' and 'reset'. Compatibility code invoked. Set _gym_disable_underscore_compat = True to disable this behavior.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# WARNING:tensorflow:From /home/scott/ScheragaThesis/baselines/baselines/common/models.py:96: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From /home/scott/ScheragaThesis/baselines/baselines/deepq/build_graph.py:189: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# /home/scott/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/scott/.local/lib/python3.6/site-packages/numpy/core/_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Logging to /tmp/openai-2021-02-27-16-19-53-651921
# --------------------------------------
# | % time spent exploring  | 96       |
# | episodes                | 10       |
# | mean 100 episode reward | 7.1      |
# | steps                   | 733      |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 92       |
# | episodes                | 20       |
# | mean 100 episode reward | 6.6      |
# | steps                   | 1.45e+03 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 89       |
# | episodes                | 30       |
# | mean 100 episode reward | 6.3      |
# | steps                   | 2.13e+03 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 86       |
# | episodes                | 40       |
# | mean 100 episode reward | 6.2      |
# | steps                   | 2.82e+03 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 82       |
# | episodes                | 50       |
# | mean 100 episode reward | 6.3      |
# | steps                   | 3.58e+03 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 78       |
# | episodes                | 60       |
# | mean 100 episode reward | 6.3      |
# | steps                   | 4.33e+03 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 75       |
# | episodes                | 70       |
# | mean 100 episode reward | 6.2      |
# | steps                   | 4.99e+03 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 72       |
# | episodes                | 80       |
# | mean 100 episode reward | 6        |
# | steps                   | 5.6e+03  |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 69       |
# | episodes                | 90       |
# | mean 100 episode reward | 5.8      |
# | steps                   | 6.16e+03 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 66       |
# | episodes                | 100      |
# | mean 100 episode reward | 5.8      |
# | steps                   | 6.83e+03 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 61       |
# | episodes                | 110      |
# | mean 100 episode reward | 6        |
# | steps                   | 7.76e+03 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 58       |
# | episodes                | 120      |
# | mean 100 episode reward | 6.1      |
# | steps                   | 8.53e+03 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 54       |
# | episodes                | 130      |
# | mean 100 episode reward | 6.2      |
# | steps                   | 9.29e+03 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 51       |
# | episodes                | 140      |
# | mean 100 episode reward | 6.2      |
# | steps                   | 9.96e+03 |
# --------------------------------------
# Saving model due to mean reward increase: None -> 6.2
# WARNING:tensorflow:From /home/scott/ScheragaThesis/baselines/baselines/common/tf_util.py:348: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From /home/scott/ScheragaThesis/baselines/baselines/common/tf_util.py:348: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# --------------------------------------
# | % time spent exploring  | 48       |
# | episodes                | 150      |
# | mean 100 episode reward | 6.1      |
# | steps                   | 1.06e+04 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 44       |
# | episodes                | 160      |
# | mean 100 episode reward | 6.1      |
# | steps                   | 1.13e+04 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 40       |
# | episodes                | 170      |
# | mean 100 episode reward | 6.3      |
# | steps                   | 1.21e+04 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 35       |
# | episodes                | 180      |
# | mean 100 episode reward | 6.7      |
# | steps                   | 1.32e+04 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 31       |
# | episodes                | 190      |
# | mean 100 episode reward | 6.9      |
# | steps                   | 1.4e+04  |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 27       |
# | episodes                | 200      |
# | mean 100 episode reward | 7        |
# | steps                   | 1.48e+04 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 19       |
# | episodes                | 210      |
# | mean 100 episode reward | 6.7      |
# | steps                   | 1.64e+04 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 11       |
# | episodes                | 220      |
# | mean 100 episode reward | 7.1      |
# | steps                   | 1.81e+04 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 230      |
# | mean 100 episode reward | 7.4      |
# | steps                   | 2e+04    |
# --------------------------------------
# Saving model due to mean reward increase: 6.2 -> 7.4
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 240      |
# | mean 100 episode reward | 7.5      |
# | steps                   | 2.12e+04 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 250      |
# | mean 100 episode reward | 7.9      |
# | steps                   | 2.28e+04 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 260      |
# | mean 100 episode reward | 7.9      |
# | steps                   | 2.43e+04 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 270      |
# | mean 100 episode reward | 7.8      |
# | steps                   | 2.55e+04 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 280      |
# | mean 100 episode reward | 7.8      |
# | steps                   | 2.76e+04 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 290      |
# | mean 100 episode reward | 8.5      |
# | steps                   | 2.99e+04 |
# --------------------------------------
# Saving model due to mean reward increase: 7.4 -> 8.5
# Saving model due to mean reward increase: 8.5 -> 15.1
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 300      |
# | mean 100 episode reward | 16.3     |
# | steps                   | 4.13e+04 |
# --------------------------------------
