# %% [markdown]
# Deep RL network to play pygame "Catcher"
#
# The code below implements the learning algorithm based on the class game_wrapper defined in game_wrapper.py. Run it stand-alone, to see how the game works. In a nutshell, the game has been tuned to move the fruit by one step for every move the paddle makes. Actions are left, still, right, and the rewards at every time step are -1 (lost), 0 (nothing), or +1 (hit paddle).

# %%
# -*- coding: utf-8 -*-
# from https://github.com/PacktPublishing/Deep-Learning-with-Keras/tree/master/Chapter08
from __future__ import division, print_function
import numpy as np
import tensorflow as tf
from tensorflow import keras
import sklearn
from keras.models import Sequential
from keras.layers.core import Activation, Dense, Flatten
from keras.layers.convolutional import Conv2D
from keras.optimizers import Adam
#from scipy.misc import imresize
from skimage.transform import resize as imresize
import collections

import os

import wrapped_game


# initialize parameters
DATA_DIR = "data"
NUM_ACTIONS = 3 # number of valid actions (left, stay, right)
GAMMA = 0.999 # decay rate of past observations
INITIAL_EPSILON = 1 # starting value of epsilon
FINAL_EPSILON = 0.1 # final value of epsilon
MEMORY_SIZE = 50000 # number of previous transitions to remember
NUM_EPOCHS_OBSERVE = 100
NUM_EPOCHS_TRAIN = 1000

BATCH_SIZE = 32
NUM_EPOCHS = NUM_EPOCHS_OBSERVE + NUM_EPOCHS_TRAIN
# Out:
# pygame 2.0.1 (SDL 2.0.14, Python 3.6.9)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %% [markdown]
# The state of the game is given by the last four images. The function below returns s_t, resizing the images to 80x80, normalizing them, and ensuring four images are returned. This is important as the first three steps of the game do not provide a history of four images. For those, the function simply replicates the same image four times.

# %%
def preprocess_images(images):
    if images.shape[0] < 4:
        # single image
        x_t = images[0]
        x_t = imresize(x_t, (80, 80))
        x_t = x_t.astype("float")
        x_t /= 255.0
        s_t = np.stack((x_t, x_t, x_t, x_t), axis=2)
    else:
        # 4 images
        xt_list = []
        for i in range(images.shape[0]):
            x_t = imresize(images[i], (80, 80))
            x_t = x_t.astype("float")
            x_t /= 255.0
            xt_list.append(x_t)
        s_t = np.stack((xt_list[0], xt_list[1], xt_list[2], xt_list[3]), 
                       axis=2)
    s_t = np.expand_dims(s_t, axis=0)
    return s_t

# %% [markdown]
# This is the core of the experience replay RL algorithm. A batch consists of batch_size state and Q-value pairs (one Q-value per action). These pairs are randomly sampled from all previous experiences.
#
# The state X is a tensor of dimension (batch_size, 80, 80, 4) as every state considers the last four iamges. The training values Y are a tensor of dimension (batch_size, 3), a Q-value for each action.
#
# These Q-values are computed by doing a prediction step using the machine learning model. Note, that two predictions are made: One to compute the Q-values for the current state s_t, the other for the next state s_tp1 that the action a_t has led to. Finally, the algorithm computes the discounted reward based on the actual reward r_t and the discounted reward of the next state. In case the game is done (game_over), there is no future step.

# %%
def get_next_batch(experience, model, num_actions, gamma, batch_size):
    batch_indices = np.random.randint(low=0, high=len(experience),
                                      size=batch_size)
    batch = [experience[i] for i in batch_indices]
    X = np.zeros((batch_size, 80, 80, 4))
    Y = np.zeros((batch_size, num_actions))
    for i in range(len(batch)):
        s_t, a_t, r_t, s_tp1, game_over = batch[i]
        X[i] = s_t
        Y[i] = model.predict(s_t)[0]
        Q_sa = np.max(model.predict(s_tp1)[0])
        if game_over:
            Y[i, a_t] = Y[i, a_t]*0.1+r_t*0.9
        else:
            Y[i, a_t] = Y[i, a_t]*0.1+(r_t + gamma * Q_sa)*0.9
    return X, Y

# %% [markdown]
# The neural network encoding the Q-table is straightforward. A (80,80,4) tensor (the last four images) serves as an input, resulting in three outputs with ReLu activation, resulting into a regression network. No max-pooling layer is used in order to maintain the actual position of the fruit and paddle.

# %%
# build the model
model = Sequential()
model.add(Conv2D(32, kernel_size=8, strides=4, 
                 kernel_initializer="normal", 
                 padding="same",
                 input_shape=(80, 80, 4)))
model.add(Activation("relu"))
model.add(Conv2D(64, kernel_size=4, strides=2, 
                 kernel_initializer="normal", 
                 padding="same"))
model.add(Activation("relu"))
model.add(Conv2D(64, kernel_size=3, strides=1,
                 kernel_initializer="normal",
                 padding="same"))
model.add(Activation("relu"))
model.add(Flatten())
model.add(Dense(512, kernel_initializer="normal"))
model.add(Activation("relu"))
model.add(Dense(3, kernel_initializer="normal"))

model.compile(optimizer=Adam(lr=1e-6), loss="mse")

# %% [markdown]
# Previous games are stored in a Python collection deque of length MEMORY_SIZE. Learning is divided into two steps: an observation phase for the first NUM_EPOCHS_OBSERVE and a training phase.
#
# The key function to run an iteration of the game is game.step(action). It returns up to four of the last frames in the vector x_t, the reward r_0 and whether the game is over. preprocess_images(x_t) then takes care of padding the images to be at least four as well as normalizing them.
#
# The algorithm calls this function over and over again, selecting a random action for the first NUM_EPOCHS_OBSERVE games, and choosing the best one with probability $1-\epsilon$ otherwise.
#
# In order to find the best action, the neural network performs a prediction step, and the action that is chosen is the one with the highest q-value.
#
# The experience is stored by pushing back the previous state (s_tm1), whatever action has been taken, the reward that resulted, the new state s_t and whether the game is over.
#
# experience.append((s_tm1, a_t, r_t, s_t, game_over))
#
# This experience is then used to incrementally train the neural network model. Finally, the learning algorithm decreases epsilon by a tiny amount.

# %%
# train network
game = wrapped_game.MyWrappedGame()
experience = collections.deque(maxlen=MEMORY_SIZE)

#fout = open(os.path.join(DATA_DIR, "rl-network-results.tsv"), "w")
num_games, num_wins = 0, 0
epsilon = INITIAL_EPSILON
for e in range(NUM_EPOCHS):
    loss = 0.0
    game.reset()
    
    # get first state
    a_0 = 1  # (0 = left, 1 = stay, 2 = right)
    x_t, r_0, game_over = game.step(a_0) 
    s_t = preprocess_images(x_t)

    while not game_over:
        s_tm1 = s_t
        # next action
        if e <= NUM_EPOCHS_OBSERVE:
            a_t = np.random.randint(low=0, high=NUM_ACTIONS, size=1)[0]
        else:
            if np.random.rand() <= epsilon:
                a_t = np.random.randint(low=0, high=NUM_ACTIONS, size=1)[0]
            else:
                q = model.predict(s_t)[0]
                a_t = np.argmax(q)
                
        # apply action, get reward
        x_t, r_t, game_over = game.step(a_t)
        s_t = preprocess_images(x_t)
        # if reward, increment num_wins
        if r_t == 1:
            num_wins += 1
        # store experience
        experience.append((s_tm1, a_t, r_t, s_t, game_over))
        
        if e > NUM_EPOCHS_OBSERVE:
            # finished observing, now start training
            # get next batch
            X, Y = get_next_batch(experience, model, NUM_ACTIONS, 
                                  GAMMA, BATCH_SIZE)
            loss += model.train_on_batch(X, Y)
        
    # reduce epsilon gradually
    if epsilon > FINAL_EPSILON:
        epsilon -= (INITIAL_EPSILON - FINAL_EPSILON) / NUM_EPOCHS
        
    print("Epoch {:04d}/{:d} | Loss {:.5f} | Win Count: {:d}"
          .format(e + 1, NUM_EPOCHS, loss, num_wins))
    #fout.write("{:04d}\t{:.5f}\t{:d}\n"
    #      .format(e + 1, loss, num_wins))

    if e % 100 == 0:
        model.save(os.path.join(DATA_DIR, "rl-network.h5"), overwrite=True)
        
#fout.close()
model.save(os.path.join(DATA_DIR, "rl-network-2100.h5"), overwrite=True)
# Out:
# Epoch 0001/1100 | Loss 0.00000 | Win Count: 1
# Epoch 0002/1100 | Loss 0.00000 | Win Count: 1
# Epoch 0003/1100 | Loss 0.00000 | Win Count: 1
# Epoch 0004/1100 | Loss 0.00000 | Win Count: 1
# Epoch 0005/1100 | Loss 0.00000 | Win Count: 2
# Epoch 0006/1100 | Loss 0.00000 | Win Count: 2
# Epoch 0007/1100 | Loss 0.00000 | Win Count: 2
# Epoch 0008/1100 | Loss 0.00000 | Win Count: 3
# Epoch 0009/1100 | Loss 0.00000 | Win Count: 3
# Epoch 0010/1100 | Loss 0.00000 | Win Count: 3
# Epoch 0011/1100 | Loss 0.00000 | Win Count: 3
# Epoch 0012/1100 | Loss 0.00000 | Win Count: 3
# Epoch 0013/1100 | Loss 0.00000 | Win Count: 3
# Epoch 0014/1100 | Loss 0.00000 | Win Count: 3
# Epoch 0015/1100 | Loss 0.00000 | Win Count: 4
# Epoch 0016/1100 | Loss 0.00000 | Win Count: 4
# Epoch 0017/1100 | Loss 0.00000 | Win Count: 4
# Epoch 0018/1100 | Loss 0.00000 | Win Count: 4
# Epoch 0019/1100 | Loss 0.00000 | Win Count: 4
# Epoch 0020/1100 | Loss 0.00000 | Win Count: 4
# Epoch 0021/1100 | Loss 0.00000 | Win Count: 4
# Epoch 0022/1100 | Loss 0.00000 | Win Count: 4
# Epoch 0023/1100 | Loss 0.00000 | Win Count: 4
# Epoch 0024/1100 | Loss 0.00000 | Win Count: 4
# Epoch 0025/1100 | Loss 0.00000 | Win Count: 4
# Epoch 0026/1100 | Loss 0.00000 | Win Count: 4
# Epoch 0027/1100 | Loss 0.00000 | Win Count: 4
# Epoch 0028/1100 | Loss 0.00000 | Win Count: 4
# Epoch 0029/1100 | Loss 0.00000 | Win Count: 4
# Epoch 0030/1100 | Loss 0.00000 | Win Count: 4
# Epoch 0031/1100 | Loss 0.00000 | Win Count: 4
# Epoch 0032/1100 | Loss 0.00000 | Win Count: 4
# Epoch 0033/1100 | Loss 0.00000 | Win Count: 4
# Epoch 0034/1100 | Loss 0.00000 | Win Count: 4
# Epoch 0035/1100 | Loss 0.00000 | Win Count: 4
# Epoch 0036/1100 | Loss 0.00000 | Win Count: 4
# Epoch 0037/1100 | Loss 0.00000 | Win Count: 4
# Epoch 0038/1100 | Loss 0.00000 | Win Count: 4
# Epoch 0039/1100 | Loss 0.00000 | Win Count: 5
# Epoch 0040/1100 | Loss 0.00000 | Win Count: 5
# Epoch 0041/1100 | Loss 0.00000 | Win Count: 5
# Epoch 0042/1100 | Loss 0.00000 | Win Count: 5
# Epoch 0043/1100 | Loss 0.00000 | Win Count: 5
# Epoch 0044/1100 | Loss 0.00000 | Win Count: 5
# Epoch 0045/1100 | Loss 0.00000 | Win Count: 6
# Epoch 0046/1100 | Loss 0.00000 | Win Count: 6
# Epoch 0047/1100 | Loss 0.00000 | Win Count: 6
# Epoch 0048/1100 | Loss 0.00000 | Win Count: 6
# Epoch 0049/1100 | Loss 0.00000 | Win Count: 6
# Epoch 0050/1100 | Loss 0.00000 | Win Count: 6
# Epoch 0051/1100 | Loss 0.00000 | Win Count: 6
# Epoch 0052/1100 | Loss 0.00000 | Win Count: 6
# Epoch 0053/1100 | Loss 0.00000 | Win Count: 6
# Epoch 0054/1100 | Loss 0.00000 | Win Count: 6
# Epoch 0055/1100 | Loss 0.00000 | Win Count: 6
# Epoch 0056/1100 | Loss 0.00000 | Win Count: 6
# Epoch 0057/1100 | Loss 0.00000 | Win Count: 6
# Epoch 0058/1100 | Loss 0.00000 | Win Count: 6
# Epoch 0059/1100 | Loss 0.00000 | Win Count: 6
# Epoch 0060/1100 | Loss 0.00000 | Win Count: 6
# Epoch 0061/1100 | Loss 0.00000 | Win Count: 6
# Epoch 0062/1100 | Loss 0.00000 | Win Count: 6
# Epoch 0063/1100 | Loss 0.00000 | Win Count: 6
# Epoch 0064/1100 | Loss 0.00000 | Win Count: 6
# Epoch 0065/1100 | Loss 0.00000 | Win Count: 6
# Epoch 0066/1100 | Loss 0.00000 | Win Count: 6
# Epoch 0067/1100 | Loss 0.00000 | Win Count: 6
# Epoch 0068/1100 | Loss 0.00000 | Win Count: 6
# Epoch 0069/1100 | Loss 0.00000 | Win Count: 6
# Epoch 0070/1100 | Loss 0.00000 | Win Count: 6
# Epoch 0071/1100 | Loss 0.00000 | Win Count: 6
# Epoch 0072/1100 | Loss 0.00000 | Win Count: 6
# Epoch 0073/1100 | Loss 0.00000 | Win Count: 6
# Epoch 0074/1100 | Loss 0.00000 | Win Count: 6
# Epoch 0075/1100 | Loss 0.00000 | Win Count: 6
# Epoch 0076/1100 | Loss 0.00000 | Win Count: 6
# Epoch 0077/1100 | Loss 0.00000 | Win Count: 6
# Epoch 0078/1100 | Loss 0.00000 | Win Count: 7
# Epoch 0079/1100 | Loss 0.00000 | Win Count: 7
# Epoch 0080/1100 | Loss 0.00000 | Win Count: 7
# Epoch 0081/1100 | Loss 0.00000 | Win Count: 7
# Epoch 0082/1100 | Loss 0.00000 | Win Count: 7
# Epoch 0083/1100 | Loss 0.00000 | Win Count: 7
# Epoch 0084/1100 | Loss 0.00000 | Win Count: 7
# Epoch 0085/1100 | Loss 0.00000 | Win Count: 7
# Epoch 0086/1100 | Loss 0.00000 | Win Count: 8
# Epoch 0087/1100 | Loss 0.00000 | Win Count: 8
# Epoch 0088/1100 | Loss 0.00000 | Win Count: 8
# Epoch 0089/1100 | Loss 0.00000 | Win Count: 8
# Epoch 0090/1100 | Loss 0.00000 | Win Count: 8
# Epoch 0091/1100 | Loss 0.00000 | Win Count: 8
# Epoch 0092/1100 | Loss 0.00000 | Win Count: 8
# Epoch 0093/1100 | Loss 0.00000 | Win Count: 8
# Epoch 0094/1100 | Loss 0.00000 | Win Count: 8
# Epoch 0095/1100 | Loss 0.00000 | Win Count: 8
# Epoch 0096/1100 | Loss 0.00000 | Win Count: 8
# Epoch 0097/1100 | Loss 0.00000 | Win Count: 8
# Epoch 0098/1100 | Loss 0.00000 | Win Count: 8
# Epoch 0099/1100 | Loss 0.00000 | Win Count: 9
# Epoch 0100/1100 | Loss 0.00000 | Win Count: 9
# Epoch 0101/1100 | Loss 0.00000 | Win Count: 9
# Epoch 0102/1100 | Loss 0.25308 | Win Count: 9
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-608cb02a3d56> in <module>
#      40             # get next batch
#      41             X, Y = get_next_batch(experience, model, NUM_ACTIONS,
# ---> 42                                   GAMMA, BATCH_SIZE)
#      43             loss += model.train_on_batch(X, Y)
#      44
#
# <ipython-input-3-0a7f8ce590f0> in get_next_batch(experience, model, num_actions, gamma, batch_size)
#       8         s_t, a_t, r_t, s_tp1, game_over = batch[i]
#       9         X[i] = s_t
# ---> 10         Y[i] = model.predict(s_t)[0]
#      11         Q_sa = np.max(model.predict(s_tp1)[0])
#      12         if game_over:
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1606           use_multiprocessing=use_multiprocessing,
#    1607           model=self,
# -> 1608           steps_per_execution=self._steps_per_execution)
#    1609
#    1610       # Container that configures and calls `tf.keras.Callback`s.
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/keras/engine/data_adapter.py in __init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution)
#    1110         use_multiprocessing=use_multiprocessing,
#    1111         distribution_strategy=ds_context.get_strategy(),
# -> 1112         model=model)
#    1113
#    1114     strategy = ds_context.get_strategy()
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/keras/engine/data_adapter.py in __init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     317     # trigger the next permutation. On the other hand, too many simultaneous
#     318     # shuffles can contend on a hardware level and degrade all performance.
# --> 319     indices_dataset = indices_dataset.map(permutation).prefetch(1)
#     320
#     321     def slice_batch_indices(indices):
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/data/ops/dataset_ops.py in map(self, map_func, num_parallel_calls, deterministic)
#    1803     """
#    1804     if num_parallel_calls is None:
# -> 1805       return MapDataset(self, map_func, preserve_cardinality=True)
#    1806     else:
#    1807       return ParallelMapDataset(
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/data/ops/dataset_ops.py in __init__(self, input_dataset, map_func, use_inter_op_parallelism, preserve_cardinality, use_legacy_function)
#    4205         self._transformation_name(),
#    4206         dataset=input_dataset,
# -> 4207         use_legacy_function=use_legacy_function)
#    4208     variant_tensor = gen_dataset_ops.map_dataset(
#    4209         input_dataset._variant_tensor,  # pylint: disable=protected-access
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/data/ops/dataset_ops.py in __init__(self, func, transformation_name, dataset, input_classes, input_shapes, input_types, input_structure, add_to_graph, use_legacy_function, defun_kwargs)
#    3523       with tracking.resource_tracker_scope(resource_tracker):
#    3524         # TODO(b/141462134): Switch to using garbage collection.
# -> 3525         self._function = wrapper_fn.get_concrete_function()
#    3526         if add_to_graph:
#    3527           self._function.add_to_graph(ops.get_default_graph())
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/eager/function.py in get_concrete_function(self, *args, **kwargs)
#    3050     """
#    3051     graph_function = self._get_concrete_function_garbage_collected(
# -> 3052         *args, **kwargs)
#    3053     graph_function._garbage_collector.release()  # pylint: disable=protected-access
#    3054     return graph_function
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/eager/function.py in _get_concrete_function_garbage_collected(self, *args, **kwargs)
#    3017       args, kwargs = None, None
#    3018     with self._lock:
# -> 3019       graph_function, _ = self._maybe_define_function(args, kwargs)
#    3020       seen_names = set()
#    3021       captured = object_identity.ObjectIdentitySet(
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/eager/function.py in _maybe_define_function(self, args, kwargs)
#    3359
#    3360           self._function_cache.missed.add(call_context_key)
# -> 3361           graph_function = self._create_graph_function(args, kwargs)
#    3362           self._function_cache.primary[cache_key] = graph_function
#    3363
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/eager/function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3204             arg_names=arg_names,
#    3205             override_flat_arg_shapes=override_flat_arg_shapes,
# -> 3206             capture_by_value=self._capture_by_value),
#    3207         self._function_attributes,
#    3208         function_spec=self.function_spec,
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes)
#     988         _, original_func = tf_decorator.unwrap(python_func)
#     989
# --> 990       func_outputs = python_func(*func_args, **func_kwargs)
#     991
#     992       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/data/ops/dataset_ops.py in wrapper_fn(*args)
#    3516           attributes=defun_kwargs)
#    3517       def wrapper_fn(*args):  # pylint: disable=missing-docstring
# -> 3518         ret = _wrapper_helper(*args)
#    3519         ret = structure.to_tensor_list(self._output_structure, ret)
#    3520         return [ops.convert_to_tensor(t) for t in ret]
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/data/ops/dataset_ops.py in _wrapper_helper(*args)
#    3451         nested_args = (nested_args,)
#    3452
# -> 3453       ret = autograph.tf_convert(func, ag_ctx)(*nested_args)
#    3454       # If `func` returns a list of tensors, `nest.flatten()` and
#    3455       # `ops.convert_to_tensor()` would conspire to attempt to stack
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/autograph/impl/api.py in wrapper(*args, **kwargs)
#     665       try:
#     666         with conversion_ctx:
# --> 667           return converted_call(f, args, kwargs, options=options)
#     668       except Exception as e:  # pylint:disable=broad-except
#     669         if hasattr(e, 'ag_error_metadata'):
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     394
#     395   if not options.user_requested and conversion.is_allowlisted(f):
# --> 396     return _call_unconverted(f, args, kwargs, options)
#     397
#     398   # internal_convert_user_code is for example turned off when issuing a dynamic
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/autograph/impl/api.py in _call_unconverted(f, args, kwargs, options, update_cache)
#     476
#     477   if kwargs is not None:
# --> 478     return f(*args, **kwargs)
#     479   return f(*args)
#     480
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/keras/engine/data_adapter.py in permutation(_)
#     308       # than reusing the same range Tensor. (presumably because of buffer
#     309       # forwarding.)
# --> 310       indices = math_ops.range(num_samples, dtype=dtypes.int64)
#     311       if shuffle and shuffle != "batch":
#     312         indices = random_ops.random_shuffle(indices)
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     199     """Call target, and fall back on dispatchers if there is a TypeError."""
#     200     try:
# --> 201       return target(*args, **kwargs)
#     202     except (TypeError, ValueError):
#     203       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py in range(start, limit, delta, dtype, name)
#    1854       start = ops.convert_to_tensor(start, dtype=dtype, name="start")
#    1855     if not isinstance(limit, ops.Tensor):
# -> 1856       limit = ops.convert_to_tensor(limit, dtype=dtype, name="limit")
#    1857     if not isinstance(delta, ops.Tensor):
#    1858       delta = ops.convert_to_tensor(delta, dtype=dtype, name="delta")
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/profiler/trace.py in wrapped(*args, **kwargs)
#     161         with Trace(trace_name, **trace_kwargs):
#     162           return func(*args, **kwargs)
# --> 163       return func(*args, **kwargs)
#     164
#     165     return wrapped
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1538
#    1539     if ret is None:
# -> 1540       ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1541
#    1542     if ret is NotImplemented:
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/framework/tensor_conversion_registry.py in _default_conversion_function(***failed resolving arguments***)
#      50 def _default_conversion_function(value, dtype, name, as_ref):
#      51   del as_ref  # Unused.
# ---> 52   return constant_op.constant(value, dtype, name=name)
#      53
#      54
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/framework/constant_op.py in constant(value, dtype, shape, name)
#     263   """
#     264   return _constant_impl(value, dtype, shape, name, verify_shape=False,
# --> 265                         allow_broadcast=True)
#     266
#     267
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/framework/constant_op.py in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     285   attrs = {"value": tensor_value, "dtype": dtype_value}
#     286   const_tensor = g._create_op_internal(  # pylint: disable=protected-access
# --> 287       "Const", [], [dtype_value.type], attrs=attrs, name=name).outputs[0]
#     288
#     289   if op_callbacks.should_invoke_op_callbacks():
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/framework/func_graph.py in _create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#     590     return super(FuncGraph, self)._create_op_internal(  # pylint: disable=protected-access
#     591         op_type, captured_inputs, dtypes, input_types, name, attrs, op_def,
# --> 592         compute_device)
#     593
#     594   def capture(self, tensor, name=None, shape=None):
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in _create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#    3534           input_types=input_types,
#    3535           original_op=self._default_original_op,
# -> 3536           op_def=op_def)
#    3537       self._create_op_helper(ret, compute_device=compute_device)
#    3538     return ret
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in __init__(self, node_def, g, inputs, output_types, control_inputs, input_types, original_op, op_def)
#    2014         op_def = self._graph._get_op_def(node_def.op)
#    2015       self._c_op = _create_c_op(self._graph, node_def, inputs,
# -> 2016                                 control_input_ops, op_def)
#    2017       name = compat.as_str(node_def.name)
#    2018     # pylint: enable=protected-access
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in _create_c_op(graph, node_def, inputs, control_inputs, op_def)
#    1848     # It might be worth creating a convenient way to re-use the same status.
#    1849     pywrap_tf_session.TF_SetAttrValueProto(op_desc, compat.as_str(name),
# -> 1850                                            serialized)
#    1851
#    1852   try:
#
# KeyboardInterrupt:

# %%
X = np.load("../data/game-screenshots.npy")
print(X.shape)

sidx = 140
for soff in range(4):
    plt.subplot(sidx + soff + 1)
    plt.imshow(X[soff].T, cmap="gray")
    plt.xticks([])
    plt.yticks([])
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-91e609103e6a> in <module>
# ----> 1 X = np.load("../data/game-screenshots.npy")
#       2 print(X.shape)
#       3
#       4 sidx = 140
#       5 for soff in range(4):
#
# ~/.local/lib/python3.6/site-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     414             own_fid = False
#     415         else:
# --> 416             fid = stack.enter_context(open(os_fspath(file), "rb"))
#     417             own_fid = True
#     418
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/game-screenshots.npy'
