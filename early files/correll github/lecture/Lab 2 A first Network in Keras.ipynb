# %% [markdown]
# ## Defining and training multi-layer artificial neural networks in Keras
#
# Fortunately, the past decade has resulted in a large number of tools to efficiently work with very large, so-called deep neural networks. Among the more prominent tools are <a href="https://en.wikipedia.org/wiki/Theano_(software)">theano</a> and <a href="https://en.wikipedia.org/wiki/TensorFlow">Tensorflow</a>, from the University of Montreal and Google Inc., respectively, and the <a href="https://en.wikipedia.org/wiki/Keras">Keras</a> library to conveniently interface with them. We will be using Keras in this class to study the most important deep neural network architectures.

# %% [markdown]
# Keras provides a series of standard models, the simplest being a sequential model that allows the user to stack layers of artifical neurons together:

# %%
from keras.models import Sequential
from keras.layers import Dense

model = Sequential()
model.add(Dense(2,input_dim=3,kernel_initializer='random_uniform'))

# %% [markdown]
# This example creates a sequential neural network with one "dense" layer with 2 artificial neurons, input dimension of 3, and uniformly random initial weights. Keras offers the following options <code>random_uniform</code>, <code>random_normal</code>, and <code>zero</code>, which are self-explanatory. Using a <i>dense</i> layer means that all inputs to a layer are connected to every neuron, and all outputs of a layer connect to all neurons of the next layer. The multi-layer perceptron shown above is a dense network.

# %% [markdown]
# ## Training a first ANN
#
# Example from Antonio Gulli, “Deep Learning with Keras.” The MNIST data set is a collection of 70000 hand-written digits from 0 to 9 that are provided in a 28x28 matrix. The MNIST data set is part of the ```keras.datasets``` <a href="https://keras.io/datasets/">library</a>. We will further import a simple ```Sequential``` model, creating a ```Dense``` model with custom ```Activation```, the ```SGD``` optimizer, which will be discussed later, and ```np_utils``` for One-Hot encoding.

# %%
import numpy as np
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers.core import Dense, Activation
from keras.optimizers import SGD
from keras.utils import np_utils
np.random.seed(1671) # for reproducibility”

# %% [markdown]
# ### Data preprocessing
#
# The following script will load the MNIST dataset (directly from the keras.datasets library) and turn the 28x28 training images into a series of one-dimensional vectors of length 784. We will also normalize the data to fall into the range from 0 to 1, and turn the class labels into one-hot encoded categorical labels.

# %%
# network and training


# data: shuffled and split between train and test sets
#
(X_train, y_train), (X_test, y_test) = mnist.load_data()
#X_train is 60000 rows of 28x28 values --> reshaped in 60000 x 784
X_train = X_train.reshape(60000, 784)
X_test = X_test.reshape(10000, 784)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
# normalize
#
X_train /= 255
X_test /= 255
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')
# convert class vectors to binary class matrices
Y_train = np_utils.to_categorical(y_train, 10)
Y_test = np_utils.to_categorical(y_test, 10)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 1s 0us/step
# 60000 train samples
# 10000 test samples

# %% [markdown]
# We can visualize the dataset using Matplotlib:

# %%
import matplotlib.pyplot as plt
for I in range(4):
    for J in range(4):
        plt.subplot(4,4,I*4+J+1)
        plt.imshow(X_train[I*4+J,:].reshape(28,28),cmap='gray')
        plt.axis('off')
#plt.tight_layout()        
plt.show()

# %% [markdown]
# ### Neural Network Model
# In a first step, we define a neural network with two layers: 10 neurons with 784 inputs and a softmax activation layer. As expected, this network has 7850 parameters, 10 times 784 for the weights and 10 for the bias values.
#
# In keras, a neural network model consists both of the architecture as well as a choice of an objective function, an optimizer, and a metrics. Note, that we are using <code>categorical_crossentropy</code>, which is more suited than <code>mean_squared_error</code> when calculating hte error between model prediction and training data. We are using stochastic gradient descent (SGD) as an optimizer, which is using data to estimate gradients vs. explicitely calculating the gradient as we have done before. The "metrics" parameter is similar to the objective function ("loss"), but is used when evaluating the model, not during training.

# %%
# 10 outputs
# final stage is softmax
model = Sequential()
model.add(Dense(10, input_shape=(784,)))
model.add(Activation('softmax'))
model.summary()

model.compile(loss='categorical_crossentropy', optimizer=SGD(), metrics=['categorical_accuracy'])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 10)                7850
# _________________________________________________________________
# activation (Activation)      (None, 10)                0
# =================================================================
# Total params: 7,850
# Trainable params: 7,850
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Training
#
# After defining the model, the optimizer, the loss function and the metric for testing, training the model is a simple call to keras' <code>fit()</code> function. We are presenting the network with 200 instances of the entire dataset ("epochs") and perform a an update of the weights every 128 training samples ("batch size"). Setting <code>verbose</code> to 1 lets us see the progress, and using 0.2 (20%) of the dataset as <code>validation_split</code> lets us observe not only the model fit, but already how the model would perform on unknown data.

# %%
history = model.fit(X_train, Y_train, batch_size=48000, epochs=200, verbose=1, validation_split=0.2)
# Out:
# Epoch 1/200
# 1/1 [==============================] - 1s 700ms/step - loss: 2.4806 - categorical_accuracy: 0.0863 - val_loss: 2.4599 - val_categorical_accuracy: 0.0865
# Epoch 2/200
# 1/1 [==============================] - 0s 54ms/step - loss: 2.4670 - categorical_accuracy: 0.0886 - val_loss: 2.4462 - val_categorical_accuracy: 0.0889
# Epoch 3/200
# 1/1 [==============================] - 0s 55ms/step - loss: 2.4536 - categorical_accuracy: 0.0911 - val_loss: 2.4328 - val_categorical_accuracy: 0.0916
# Epoch 4/200
# 1/1 [==============================] - 0s 54ms/step - loss: 2.4405 - categorical_accuracy: 0.0943 - val_loss: 2.4196 - val_categorical_accuracy: 0.0955
# Epoch 5/200
# 1/1 [==============================] - 0s 55ms/step - loss: 2.4276 - categorical_accuracy: 0.0974 - val_loss: 2.4067 - val_categorical_accuracy: 0.0983
# Epoch 6/200
# 1/1 [==============================] - 0s 54ms/step - loss: 2.4149 - categorical_accuracy: 0.1012 - val_loss: 2.3940 - val_categorical_accuracy: 0.1028
# Epoch 7/200
# 1/1 [==============================] - 0s 53ms/step - loss: 2.4025 - categorical_accuracy: 0.1050 - val_loss: 2.3814 - val_categorical_accuracy: 0.1072
# Epoch 8/200
# 1/1 [==============================] - 0s 56ms/step - loss: 2.3902 - categorical_accuracy: 0.1086 - val_loss: 2.3691 - val_categorical_accuracy: 0.1117
# Epoch 9/200
# 1/1 [==============================] - 0s 58ms/step - loss: 2.3782 - categorical_accuracy: 0.1126 - val_loss: 2.3570 - val_categorical_accuracy: 0.1179
# Epoch 10/200
# 1/1 [==============================] - 0s 54ms/step - loss: 2.3663 - categorical_accuracy: 0.1174 - val_loss: 2.3450 - val_categorical_accuracy: 0.1231
# Epoch 11/200
# 1/1 [==============================] - 0s 60ms/step - loss: 2.3546 - categorical_accuracy: 0.1223 - val_loss: 2.3332 - val_categorical_accuracy: 0.1284
# Epoch 12/200
# 1/1 [==============================] - 0s 58ms/step - loss: 2.3431 - categorical_accuracy: 0.1276 - val_loss: 2.3216 - val_categorical_accuracy: 0.1339
# Epoch 13/200
# 1/1 [==============================] - 0s 59ms/step - loss: 2.3317 - categorical_accuracy: 0.1338 - val_loss: 2.3102 - val_categorical_accuracy: 0.1404
# Epoch 14/200
# 1/1 [==============================] - 0s 56ms/step - loss: 2.3205 - categorical_accuracy: 0.1402 - val_loss: 2.2988 - val_categorical_accuracy: 0.1469
# Epoch 15/200
# 1/1 [==============================] - 0s 60ms/step - loss: 2.3094 - categorical_accuracy: 0.1463 - val_loss: 2.2877 - val_categorical_accuracy: 0.1530
# Epoch 16/200
# 1/1 [==============================] - 0s 61ms/step - loss: 2.2985 - categorical_accuracy: 0.1524 - val_loss: 2.2766 - val_categorical_accuracy: 0.1595
# Epoch 17/200
# 1/1 [==============================] - 0s 60ms/step - loss: 2.2877 - categorical_accuracy: 0.1585 - val_loss: 2.2658 - val_categorical_accuracy: 0.1658
# Epoch 18/200
# 1/1 [==============================] - 0s 58ms/step - loss: 2.2771 - categorical_accuracy: 0.1647 - val_loss: 2.2550 - val_categorical_accuracy: 0.1721
# Epoch 19/200
# 1/1 [==============================] - 0s 61ms/step - loss: 2.2666 - categorical_accuracy: 0.1712 - val_loss: 2.2443 - val_categorical_accuracy: 0.1802
# Epoch 20/200
# 1/1 [==============================] - 0s 58ms/step - loss: 2.2562 - categorical_accuracy: 0.1779 - val_loss: 2.2338 - val_categorical_accuracy: 0.1867
# Epoch 21/200
# 1/1 [==============================] - 0s 55ms/step - loss: 2.2459 - categorical_accuracy: 0.1861 - val_loss: 2.2234 - val_categorical_accuracy: 0.1942
# Epoch 22/200
# 1/1 [==============================] - 0s 58ms/step - loss: 2.2357 - categorical_accuracy: 0.1936 - val_loss: 2.2131 - val_categorical_accuracy: 0.2013
# Epoch 23/200
# 1/1 [==============================] - 0s 53ms/step - loss: 2.2256 - categorical_accuracy: 0.2007 - val_loss: 2.2029 - val_categorical_accuracy: 0.2087
# Epoch 24/200
# 1/1 [==============================] - 0s 61ms/step - loss: 2.2156 - categorical_accuracy: 0.2085 - val_loss: 2.1928 - val_categorical_accuracy: 0.2153
# Epoch 25/200
# 1/1 [==============================] - 0s 62ms/step - loss: 2.2058 - categorical_accuracy: 0.2155 - val_loss: 2.1828 - val_categorical_accuracy: 0.2230
# Epoch 26/200
# 1/1 [==============================] - 0s 54ms/step - loss: 2.1960 - categorical_accuracy: 0.2236 - val_loss: 2.1729 - val_categorical_accuracy: 0.2308
# Epoch 27/200
# 1/1 [==============================] - 0s 55ms/step - loss: 2.1863 - categorical_accuracy: 0.2315 - val_loss: 2.1631 - val_categorical_accuracy: 0.2406
# Epoch 28/200
# 1/1 [==============================] - 0s 67ms/step - loss: 2.1767 - categorical_accuracy: 0.2395 - val_loss: 2.1534 - val_categorical_accuracy: 0.2495
# Epoch 29/200
# 1/1 [==============================] - 0s 59ms/step - loss: 2.1672 - categorical_accuracy: 0.2466 - val_loss: 2.1438 - val_categorical_accuracy: 0.2569
# Epoch 30/200
# 1/1 [==============================] - 0s 56ms/step - loss: 2.1578 - categorical_accuracy: 0.2548 - val_loss: 2.1342 - val_categorical_accuracy: 0.2668
# Epoch 31/200
# 1/1 [==============================] - 0s 58ms/step - loss: 2.1485 - categorical_accuracy: 0.2627 - val_loss: 2.1248 - val_categorical_accuracy: 0.2768
# Epoch 32/200
# 1/1 [==============================] - 0s 59ms/step - loss: 2.1392 - categorical_accuracy: 0.2703 - val_loss: 2.1154 - val_categorical_accuracy: 0.2854
# Epoch 33/200
# 1/1 [==============================] - 0s 58ms/step - loss: 2.1301 - categorical_accuracy: 0.2780 - val_loss: 2.1061 - val_categorical_accuracy: 0.2955
# Epoch 34/200
# 1/1 [==============================] - 0s 58ms/step - loss: 2.1210 - categorical_accuracy: 0.2862 - val_loss: 2.0969 - val_categorical_accuracy: 0.3027
# Epoch 35/200
# 1/1 [==============================] - 0s 59ms/step - loss: 2.1120 - categorical_accuracy: 0.2946 - val_loss: 2.0878 - val_categorical_accuracy: 0.3128
# Epoch 36/200
# 1/1 [==============================] - 0s 58ms/step - loss: 2.1031 - categorical_accuracy: 0.3019 - val_loss: 2.0787 - val_categorical_accuracy: 0.3204
# Epoch 37/200
# 1/1 [==============================] - 0s 57ms/step - loss: 2.0942 - categorical_accuracy: 0.3101 - val_loss: 2.0698 - val_categorical_accuracy: 0.3303
# Epoch 38/200
# 1/1 [==============================] - 0s 58ms/step - loss: 2.0854 - categorical_accuracy: 0.3182 - val_loss: 2.0609 - val_categorical_accuracy: 0.3395
# Epoch 39/200
# 1/1 [==============================] - 0s 59ms/step - loss: 2.0767 - categorical_accuracy: 0.3257 - val_loss: 2.0520 - val_categorical_accuracy: 0.3479
# Epoch 40/200
# 1/1 [==============================] - 0s 63ms/step - loss: 2.0681 - categorical_accuracy: 0.3341 - val_loss: 2.0433 - val_categorical_accuracy: 0.3556
# Epoch 41/200
# 1/1 [==============================] - 0s 56ms/step - loss: 2.0595 - categorical_accuracy: 0.3418 - val_loss: 2.0346 - val_categorical_accuracy: 0.3649
# Epoch 42/200
# 1/1 [==============================] - 0s 55ms/step - loss: 2.0510 - categorical_accuracy: 0.3490 - val_loss: 2.0259 - val_categorical_accuracy: 0.3729
# Epoch 43/200
# 1/1 [==============================] - 0s 56ms/step - loss: 2.0425 - categorical_accuracy: 0.3561 - val_loss: 2.0174 - val_categorical_accuracy: 0.3812
# Epoch 44/200
# 1/1 [==============================] - 0s 54ms/step - loss: 2.0342 - categorical_accuracy: 0.3631 - val_loss: 2.0089 - val_categorical_accuracy: 0.3892
# Epoch 45/200
# 1/1 [==============================] - 0s 56ms/step - loss: 2.0259 - categorical_accuracy: 0.3707 - val_loss: 2.0005 - val_categorical_accuracy: 0.3958
# Epoch 46/200
# 1/1 [==============================] - 0s 59ms/step - loss: 2.0176 - categorical_accuracy: 0.3780 - val_loss: 1.9921 - val_categorical_accuracy: 0.4047
# Epoch 47/200
# 1/1 [==============================] - 0s 59ms/step - loss: 2.0094 - categorical_accuracy: 0.3853 - val_loss: 1.9838 - val_categorical_accuracy: 0.4128
# Epoch 48/200
# 1/1 [==============================] - 0s 58ms/step - loss: 2.0013 - categorical_accuracy: 0.3930 - val_loss: 1.9756 - val_categorical_accuracy: 0.4199
# Epoch 49/200
# 1/1 [==============================] - 0s 115ms/step - loss: 1.9933 - categorical_accuracy: 0.4001 - val_loss: 1.9674 - val_categorical_accuracy: 0.4263
# Epoch 50/200
# 1/1 [==============================] - 0s 53ms/step - loss: 1.9853 - categorical_accuracy: 0.4078 - val_loss: 1.9593 - val_categorical_accuracy: 0.4335
# Epoch 51/200
# 1/1 [==============================] - 0s 56ms/step - loss: 1.9773 - categorical_accuracy: 0.4142 - val_loss: 1.9513 - val_categorical_accuracy: 0.4402
# Epoch 52/200
# 1/1 [==============================] - 0s 55ms/step - loss: 1.9695 - categorical_accuracy: 0.4202 - val_loss: 1.9433 - val_categorical_accuracy: 0.4480
# Epoch 53/200
# 1/1 [==============================] - 0s 58ms/step - loss: 1.9616 - categorical_accuracy: 0.4266 - val_loss: 1.9353 - val_categorical_accuracy: 0.4556
# Epoch 54/200
# 1/1 [==============================] - 0s 54ms/step - loss: 1.9539 - categorical_accuracy: 0.4332 - val_loss: 1.9275 - val_categorical_accuracy: 0.4619
# Epoch 55/200
# 1/1 [==============================] - 0s 58ms/step - loss: 1.9462 - categorical_accuracy: 0.4389 - val_loss: 1.9197 - val_categorical_accuracy: 0.4667
# Epoch 56/200
# 1/1 [==============================] - 0s 57ms/step - loss: 1.9385 - categorical_accuracy: 0.4451 - val_loss: 1.9119 - val_categorical_accuracy: 0.4734
# Epoch 57/200
# 1/1 [==============================] - 0s 55ms/step - loss: 1.9309 - categorical_accuracy: 0.4513 - val_loss: 1.9042 - val_categorical_accuracy: 0.4793
# Epoch 58/200
# 1/1 [==============================] - 0s 55ms/step - loss: 1.9234 - categorical_accuracy: 0.4573 - val_loss: 1.8966 - val_categorical_accuracy: 0.4853
# Epoch 59/200
# 1/1 [==============================] - 0s 55ms/step - loss: 1.9159 - categorical_accuracy: 0.4638 - val_loss: 1.8890 - val_categorical_accuracy: 0.4910
# Epoch 60/200
# 1/1 [==============================] - 0s 55ms/step - loss: 1.9085 - categorical_accuracy: 0.4697 - val_loss: 1.8815 - val_categorical_accuracy: 0.4978
# Epoch 61/200
# 1/1 [==============================] - 0s 57ms/step - loss: 1.9011 - categorical_accuracy: 0.4761 - val_loss: 1.8740 - val_categorical_accuracy: 0.5034
# Epoch 62/200
# 1/1 [==============================] - 0s 56ms/step - loss: 1.8938 - categorical_accuracy: 0.4817 - val_loss: 1.8666 - val_categorical_accuracy: 0.5098
# Epoch 63/200
# 1/1 [==============================] - 0s 59ms/step - loss: 1.8865 - categorical_accuracy: 0.4882 - val_loss: 1.8592 - val_categorical_accuracy: 0.5147
# Epoch 64/200
# 1/1 [==============================] - 0s 58ms/step - loss: 1.8793 - categorical_accuracy: 0.4933 - val_loss: 1.8519 - val_categorical_accuracy: 0.5193
# Epoch 65/200
# 1/1 [==============================] - 0s 54ms/step - loss: 1.8722 - categorical_accuracy: 0.4991 - val_loss: 1.8446 - val_categorical_accuracy: 0.5240
# Epoch 66/200
# 1/1 [==============================] - 0s 55ms/step - loss: 1.8651 - categorical_accuracy: 0.5047 - val_loss: 1.8374 - val_categorical_accuracy: 0.5298
# Epoch 67/200
# 1/1 [==============================] - 0s 56ms/step - loss: 1.8580 - categorical_accuracy: 0.5101 - val_loss: 1.8303 - val_categorical_accuracy: 0.5366
# Epoch 68/200
# 1/1 [==============================] - 0s 58ms/step - loss: 1.8510 - categorical_accuracy: 0.5151 - val_loss: 1.8232 - val_categorical_accuracy: 0.5412
# Epoch 69/200
# 1/1 [==============================] - 0s 58ms/step - loss: 1.8441 - categorical_accuracy: 0.5205 - val_loss: 1.8161 - val_categorical_accuracy: 0.5471
# Epoch 70/200
# 1/1 [==============================] - 0s 58ms/step - loss: 1.8372 - categorical_accuracy: 0.5259 - val_loss: 1.8091 - val_categorical_accuracy: 0.5529
# Epoch 71/200
# 1/1 [==============================] - 0s 59ms/step - loss: 1.8303 - categorical_accuracy: 0.5310 - val_loss: 1.8022 - val_categorical_accuracy: 0.5577
# Epoch 72/200
# 1/1 [==============================] - 0s 58ms/step - loss: 1.8235 - categorical_accuracy: 0.5360 - val_loss: 1.7953 - val_categorical_accuracy: 0.5619
# Epoch 73/200
# 1/1 [==============================] - 0s 61ms/step - loss: 1.8168 - categorical_accuracy: 0.5406 - val_loss: 1.7884 - val_categorical_accuracy: 0.5677
# Epoch 74/200
# 1/1 [==============================] - 0s 58ms/step - loss: 1.8101 - categorical_accuracy: 0.5453 - val_loss: 1.7816 - val_categorical_accuracy: 0.5726
# Epoch 75/200
# 1/1 [==============================] - 0s 58ms/step - loss: 1.8034 - categorical_accuracy: 0.5497 - val_loss: 1.7749 - val_categorical_accuracy: 0.5763
# Epoch 76/200
# 1/1 [==============================] - 0s 58ms/step - loss: 1.7968 - categorical_accuracy: 0.5536 - val_loss: 1.7682 - val_categorical_accuracy: 0.5815
# Epoch 77/200
# 1/1 [==============================] - 0s 58ms/step - loss: 1.7902 - categorical_accuracy: 0.5581 - val_loss: 1.7615 - val_categorical_accuracy: 0.5853
# Epoch 78/200
# 1/1 [==============================] - 0s 57ms/step - loss: 1.7837 - categorical_accuracy: 0.5622 - val_loss: 1.7549 - val_categorical_accuracy: 0.5893
# Epoch 79/200
# 1/1 [==============================] - 0s 60ms/step - loss: 1.7773 - categorical_accuracy: 0.5659 - val_loss: 1.7484 - val_categorical_accuracy: 0.5941
# Epoch 80/200
# 1/1 [==============================] - 0s 58ms/step - loss: 1.7708 - categorical_accuracy: 0.5699 - val_loss: 1.7419 - val_categorical_accuracy: 0.5979
# Epoch 81/200
# 1/1 [==============================] - 0s 55ms/step - loss: 1.7645 - categorical_accuracy: 0.5740 - val_loss: 1.7354 - val_categorical_accuracy: 0.6019
# Epoch 82/200
# 1/1 [==============================] - 0s 55ms/step - loss: 1.7581 - categorical_accuracy: 0.5777 - val_loss: 1.7290 - val_categorical_accuracy: 0.6058
# Epoch 83/200
# 1/1 [==============================] - 0s 61ms/step - loss: 1.7519 - categorical_accuracy: 0.5815 - val_loss: 1.7226 - val_categorical_accuracy: 0.6105
# Epoch 84/200
# 1/1 [==============================] - 0s 60ms/step - loss: 1.7456 - categorical_accuracy: 0.5851 - val_loss: 1.7163 - val_categorical_accuracy: 0.6136
# Epoch 85/200
# 1/1 [==============================] - 0s 58ms/step - loss: 1.7394 - categorical_accuracy: 0.5882 - val_loss: 1.7100 - val_categorical_accuracy: 0.6173
# Epoch 86/200
# 1/1 [==============================] - 0s 59ms/step - loss: 1.7333 - categorical_accuracy: 0.5920 - val_loss: 1.7038 - val_categorical_accuracy: 0.6203
# Epoch 87/200
# 1/1 [==============================] - 0s 64ms/step - loss: 1.7272 - categorical_accuracy: 0.5955 - val_loss: 1.6976 - val_categorical_accuracy: 0.6243
# Epoch 88/200
# 1/1 [==============================] - 0s 56ms/step - loss: 1.7211 - categorical_accuracy: 0.5991 - val_loss: 1.6914 - val_categorical_accuracy: 0.6283
# Epoch 89/200
# 1/1 [==============================] - 0s 118ms/step - loss: 1.7151 - categorical_accuracy: 0.6021 - val_loss: 1.6854 - val_categorical_accuracy: 0.6323
# Epoch 90/200
# 1/1 [==============================] - 0s 59ms/step - loss: 1.7092 - categorical_accuracy: 0.6050 - val_loss: 1.6793 - val_categorical_accuracy: 0.6350
# Epoch 91/200
# 1/1 [==============================] - 0s 61ms/step - loss: 1.7032 - categorical_accuracy: 0.6077 - val_loss: 1.6733 - val_categorical_accuracy: 0.6381
# Epoch 92/200
# 1/1 [==============================] - 0s 60ms/step - loss: 1.6973 - categorical_accuracy: 0.6104 - val_loss: 1.6673 - val_categorical_accuracy: 0.6406
# Epoch 93/200
# 1/1 [==============================] - 0s 59ms/step - loss: 1.6915 - categorical_accuracy: 0.6133 - val_loss: 1.6614 - val_categorical_accuracy: 0.6429
# Epoch 94/200
# 1/1 [==============================] - 0s 60ms/step - loss: 1.6857 - categorical_accuracy: 0.6158 - val_loss: 1.6555 - val_categorical_accuracy: 0.6457
# Epoch 95/200
# 1/1 [==============================] - 0s 60ms/step - loss: 1.6800 - categorical_accuracy: 0.6188 - val_loss: 1.6497 - val_categorical_accuracy: 0.6485
# Epoch 96/200
# 1/1 [==============================] - 0s 61ms/step - loss: 1.6742 - categorical_accuracy: 0.6215 - val_loss: 1.6439 - val_categorical_accuracy: 0.6515
# Epoch 97/200
# 1/1 [==============================] - 0s 62ms/step - loss: 1.6686 - categorical_accuracy: 0.6241 - val_loss: 1.6381 - val_categorical_accuracy: 0.6541
# Epoch 98/200
# 1/1 [==============================] - 0s 57ms/step - loss: 1.6629 - categorical_accuracy: 0.6266 - val_loss: 1.6324 - val_categorical_accuracy: 0.6565
# Epoch 99/200
# 1/1 [==============================] - 0s 57ms/step - loss: 1.6573 - categorical_accuracy: 0.6290 - val_loss: 1.6267 - val_categorical_accuracy: 0.6587
# Epoch 100/200
# 1/1 [==============================] - 0s 55ms/step - loss: 1.6518 - categorical_accuracy: 0.6316 - val_loss: 1.6211 - val_categorical_accuracy: 0.6603
# Epoch 101/200
# 1/1 [==============================] - 0s 59ms/step - loss: 1.6463 - categorical_accuracy: 0.6339 - val_loss: 1.6155 - val_categorical_accuracy: 0.6620
# Epoch 102/200
# 1/1 [==============================] - 0s 57ms/step - loss: 1.6408 - categorical_accuracy: 0.6364 - val_loss: 1.6099 - val_categorical_accuracy: 0.6638
# Epoch 103/200
# 1/1 [==============================] - 0s 57ms/step - loss: 1.6354 - categorical_accuracy: 0.6385 - val_loss: 1.6044 - val_categorical_accuracy: 0.6663
# Epoch 104/200
# 1/1 [==============================] - 0s 58ms/step - loss: 1.6300 - categorical_accuracy: 0.6406 - val_loss: 1.5990 - val_categorical_accuracy: 0.6684
# Epoch 105/200
# 1/1 [==============================] - ETA: 0s - loss: 1.6246 - categorical_accuracy: 0.64 - 0s 58ms/step - loss: 1.6246 - categorical_accuracy: 0.6429 - val_loss: 1.5935 - val_categorical_accuracy: 0.6702
# Epoch 106/200
# 1/1 [==============================] - 0s 57ms/step - loss: 1.6193 - categorical_accuracy: 0.6452 - val_loss: 1.5881 - val_categorical_accuracy: 0.6727
# Epoch 107/200
# 1/1 [==============================] - 0s 54ms/step - loss: 1.6140 - categorical_accuracy: 0.6471 - val_loss: 1.5828 - val_categorical_accuracy: 0.6744
# Epoch 108/200
# 1/1 [==============================] - 0s 58ms/step - loss: 1.6088 - categorical_accuracy: 0.6493 - val_loss: 1.5775 - val_categorical_accuracy: 0.6760
# Epoch 109/200
# 1/1 [==============================] - 0s 62ms/step - loss: 1.6036 - categorical_accuracy: 0.6515 - val_loss: 1.5722 - val_categorical_accuracy: 0.6790
# Epoch 110/200
# 1/1 [==============================] - 0s 60ms/step - loss: 1.5984 - categorical_accuracy: 0.6538 - val_loss: 1.5669 - val_categorical_accuracy: 0.6810
# Epoch 111/200
# 1/1 [==============================] - 0s 59ms/step - loss: 1.5933 - categorical_accuracy: 0.6556 - val_loss: 1.5617 - val_categorical_accuracy: 0.6820
# Epoch 112/200
# 1/1 [==============================] - 0s 57ms/step - loss: 1.5882 - categorical_accuracy: 0.6573 - val_loss: 1.5566 - val_categorical_accuracy: 0.6847
# Epoch 113/200
# 1/1 [==============================] - 0s 58ms/step - loss: 1.5831 - categorical_accuracy: 0.6590 - val_loss: 1.5514 - val_categorical_accuracy: 0.6872
# Epoch 114/200
# 1/1 [==============================] - 0s 57ms/step - loss: 1.5781 - categorical_accuracy: 0.6610 - val_loss: 1.5463 - val_categorical_accuracy: 0.6889
# Epoch 115/200
# 1/1 [==============================] - 0s 55ms/step - loss: 1.5731 - categorical_accuracy: 0.6628 - val_loss: 1.5413 - val_categorical_accuracy: 0.6904
# Epoch 116/200
# 1/1 [==============================] - 0s 59ms/step - loss: 1.5682 - categorical_accuracy: 0.6648 - val_loss: 1.5363 - val_categorical_accuracy: 0.6921
# Epoch 117/200
# 1/1 [==============================] - 0s 59ms/step - loss: 1.5633 - categorical_accuracy: 0.6666 - val_loss: 1.5313 - val_categorical_accuracy: 0.6935
# Epoch 118/200
# 1/1 [==============================] - 0s 59ms/step - loss: 1.5584 - categorical_accuracy: 0.6682 - val_loss: 1.5263 - val_categorical_accuracy: 0.6955
# Epoch 119/200
# 1/1 [==============================] - 0s 58ms/step - loss: 1.5536 - categorical_accuracy: 0.6699 - val_loss: 1.5214 - val_categorical_accuracy: 0.6970
# Epoch 120/200
# 1/1 [==============================] - 0s 58ms/step - loss: 1.5488 - categorical_accuracy: 0.6716 - val_loss: 1.5165 - val_categorical_accuracy: 0.6985
# Epoch 121/200
# 1/1 [==============================] - 0s 56ms/step - loss: 1.5440 - categorical_accuracy: 0.6735 - val_loss: 1.5117 - val_categorical_accuracy: 0.7001
# Epoch 122/200
# 1/1 [==============================] - 0s 56ms/step - loss: 1.5392 - categorical_accuracy: 0.6751 - val_loss: 1.5069 - val_categorical_accuracy: 0.7017
# Epoch 123/200
# 1/1 [==============================] - 0s 58ms/step - loss: 1.5345 - categorical_accuracy: 0.6767 - val_loss: 1.5021 - val_categorical_accuracy: 0.7036
# Epoch 124/200
# 1/1 [==============================] - 0s 58ms/step - loss: 1.5299 - categorical_accuracy: 0.6782 - val_loss: 1.4973 - val_categorical_accuracy: 0.7049
# Epoch 125/200
# 1/1 [==============================] - 0s 58ms/step - loss: 1.5252 - categorical_accuracy: 0.6794 - val_loss: 1.4926 - val_categorical_accuracy: 0.7060
# Epoch 126/200
# 1/1 [==============================] - 0s 59ms/step - loss: 1.5206 - categorical_accuracy: 0.6807 - val_loss: 1.4880 - val_categorical_accuracy: 0.7080
# Epoch 127/200
# 1/1 [==============================] - 0s 58ms/step - loss: 1.5160 - categorical_accuracy: 0.6824 - val_loss: 1.4833 - val_categorical_accuracy: 0.7091
# Epoch 128/200
# 1/1 [==============================] - 0s 57ms/step - loss: 1.5115 - categorical_accuracy: 0.6841 - val_loss: 1.4787 - val_categorical_accuracy: 0.7105
# Epoch 129/200
# 1/1 [==============================] - 0s 61ms/step - loss: 1.5070 - categorical_accuracy: 0.6855 - val_loss: 1.4741 - val_categorical_accuracy: 0.7117
# Epoch 130/200
# 1/1 [==============================] - 0s 57ms/step - loss: 1.5025 - categorical_accuracy: 0.6866 - val_loss: 1.4696 - val_categorical_accuracy: 0.7129
# Epoch 131/200
# 1/1 [==============================] - 0s 59ms/step - loss: 1.4981 - categorical_accuracy: 0.6881 - val_loss: 1.4651 - val_categorical_accuracy: 0.7140
# Epoch 132/200
# 1/1 [==============================] - 0s 56ms/step - loss: 1.4937 - categorical_accuracy: 0.6893 - val_loss: 1.4606 - val_categorical_accuracy: 0.7157
# Epoch 133/200
# 1/1 [==============================] - 0s 56ms/step - loss: 1.4893 - categorical_accuracy: 0.6910 - val_loss: 1.4561 - val_categorical_accuracy: 0.7172
# Epoch 134/200
# 1/1 [==============================] - 0s 58ms/step - loss: 1.4849 - categorical_accuracy: 0.6923 - val_loss: 1.4517 - val_categorical_accuracy: 0.7183
# Epoch 135/200
# 1/1 [==============================] - 0s 54ms/step - loss: 1.4806 - categorical_accuracy: 0.6936 - val_loss: 1.4473 - val_categorical_accuracy: 0.7203
# Epoch 136/200
# 1/1 [==============================] - 0s 58ms/step - loss: 1.4763 - categorical_accuracy: 0.6945 - val_loss: 1.4430 - val_categorical_accuracy: 0.7215
# Epoch 137/200
# 1/1 [==============================] - 0s 59ms/step - loss: 1.4720 - categorical_accuracy: 0.6954 - val_loss: 1.4386 - val_categorical_accuracy: 0.7225
# Epoch 138/200
# 1/1 [==============================] - 0s 61ms/step - loss: 1.4678 - categorical_accuracy: 0.6961 - val_loss: 1.4343 - val_categorical_accuracy: 0.7237
# Epoch 139/200
# 1/1 [==============================] - 0s 118ms/step - loss: 1.4636 - categorical_accuracy: 0.6972 - val_loss: 1.4301 - val_categorical_accuracy: 0.7248
# Epoch 140/200
# 1/1 [==============================] - 0s 58ms/step - loss: 1.4594 - categorical_accuracy: 0.6984 - val_loss: 1.4258 - val_categorical_accuracy: 0.7258
# Epoch 141/200
# 1/1 [==============================] - 0s 59ms/step - loss: 1.4553 - categorical_accuracy: 0.6996 - val_loss: 1.4216 - val_categorical_accuracy: 0.7270
# Epoch 142/200
# 1/1 [==============================] - 0s 59ms/step - loss: 1.4512 - categorical_accuracy: 0.7004 - val_loss: 1.4174 - val_categorical_accuracy: 0.7279
# Epoch 143/200
# 1/1 [==============================] - 0s 56ms/step - loss: 1.4471 - categorical_accuracy: 0.7013 - val_loss: 1.4133 - val_categorical_accuracy: 0.7285
# Epoch 144/200
# 1/1 [==============================] - 0s 60ms/step - loss: 1.4430 - categorical_accuracy: 0.7025 - val_loss: 1.4092 - val_categorical_accuracy: 0.7298
# Epoch 145/200
# 1/1 [==============================] - 0s 63ms/step - loss: 1.4390 - categorical_accuracy: 0.7039 - val_loss: 1.4051 - val_categorical_accuracy: 0.7313
# Epoch 146/200
# 1/1 [==============================] - 0s 61ms/step - loss: 1.4350 - categorical_accuracy: 0.7048 - val_loss: 1.4010 - val_categorical_accuracy: 0.7325
# Epoch 147/200
# 1/1 [==============================] - 0s 61ms/step - loss: 1.4310 - categorical_accuracy: 0.7061 - val_loss: 1.3970 - val_categorical_accuracy: 0.7342
# Epoch 148/200
# 1/1 [==============================] - 0s 59ms/step - loss: 1.4271 - categorical_accuracy: 0.7071 - val_loss: 1.3929 - val_categorical_accuracy: 0.7353
# Epoch 149/200
# 1/1 [==============================] - 0s 57ms/step - loss: 1.4232 - categorical_accuracy: 0.7082 - val_loss: 1.3890 - val_categorical_accuracy: 0.7362
# Epoch 150/200
# 1/1 [==============================] - 0s 56ms/step - loss: 1.4193 - categorical_accuracy: 0.7094 - val_loss: 1.3850 - val_categorical_accuracy: 0.7368
# Epoch 151/200
# 1/1 [==============================] - 0s 65ms/step - loss: 1.4154 - categorical_accuracy: 0.7103 - val_loss: 1.3811 - val_categorical_accuracy: 0.7377
# Epoch 152/200
# 1/1 [==============================] - 0s 59ms/step - loss: 1.4116 - categorical_accuracy: 0.7109 - val_loss: 1.3772 - val_categorical_accuracy: 0.7381
# Epoch 153/200
# 1/1 [==============================] - 0s 56ms/step - loss: 1.4077 - categorical_accuracy: 0.7117 - val_loss: 1.3733 - val_categorical_accuracy: 0.7387
# Epoch 154/200
# 1/1 [==============================] - 0s 60ms/step - loss: 1.4039 - categorical_accuracy: 0.7124 - val_loss: 1.3695 - val_categorical_accuracy: 0.7398
# Epoch 155/200
# 1/1 [==============================] - 0s 60ms/step - loss: 1.4002 - categorical_accuracy: 0.7136 - val_loss: 1.3656 - val_categorical_accuracy: 0.7406
# Epoch 156/200
# 1/1 [==============================] - 0s 59ms/step - loss: 1.3965 - categorical_accuracy: 0.7146 - val_loss: 1.3618 - val_categorical_accuracy: 0.7418
# Epoch 157/200
# 1/1 [==============================] - 0s 59ms/step - loss: 1.3927 - categorical_accuracy: 0.7154 - val_loss: 1.3581 - val_categorical_accuracy: 0.7429
# Epoch 158/200
# 1/1 [==============================] - 0s 60ms/step - loss: 1.3891 - categorical_accuracy: 0.7164 - val_loss: 1.3543 - val_categorical_accuracy: 0.7441
# Epoch 159/200
# 1/1 [==============================] - 0s 54ms/step - loss: 1.3854 - categorical_accuracy: 0.7171 - val_loss: 1.3506 - val_categorical_accuracy: 0.7451
# Epoch 160/200
# 1/1 [==============================] - 0s 56ms/step - loss: 1.3818 - categorical_accuracy: 0.7179 - val_loss: 1.3469 - val_categorical_accuracy: 0.7461
# Epoch 161/200
# 1/1 [==============================] - 0s 58ms/step - loss: 1.3781 - categorical_accuracy: 0.7187 - val_loss: 1.3432 - val_categorical_accuracy: 0.7471
# Epoch 162/200
# 1/1 [==============================] - 0s 54ms/step - loss: 1.3746 - categorical_accuracy: 0.7196 - val_loss: 1.3396 - val_categorical_accuracy: 0.7477
# Epoch 163/200
# 1/1 [==============================] - 0s 57ms/step - loss: 1.3710 - categorical_accuracy: 0.7202 - val_loss: 1.3360 - val_categorical_accuracy: 0.7487
# Epoch 164/200
# 1/1 [==============================] - 0s 61ms/step - loss: 1.3675 - categorical_accuracy: 0.7210 - val_loss: 1.3324 - val_categorical_accuracy: 0.7494
# Epoch 165/200
# 1/1 [==============================] - 0s 52ms/step - loss: 1.3639 - categorical_accuracy: 0.7219 - val_loss: 1.3288 - val_categorical_accuracy: 0.7508
# Epoch 166/200
# 1/1 [==============================] - 0s 56ms/step - loss: 1.3604 - categorical_accuracy: 0.7227 - val_loss: 1.3252 - val_categorical_accuracy: 0.7513
# Epoch 167/200
# 1/1 [==============================] - 0s 56ms/step - loss: 1.3570 - categorical_accuracy: 0.7235 - val_loss: 1.3217 - val_categorical_accuracy: 0.7521
# Epoch 168/200
# 1/1 [==============================] - 0s 54ms/step - loss: 1.3535 - categorical_accuracy: 0.7244 - val_loss: 1.3182 - val_categorical_accuracy: 0.7530
# Epoch 169/200
# 1/1 [==============================] - 0s 53ms/step - loss: 1.3501 - categorical_accuracy: 0.7253 - val_loss: 1.3147 - val_categorical_accuracy: 0.7535
# Epoch 170/200
# 1/1 [==============================] - 0s 57ms/step - loss: 1.3467 - categorical_accuracy: 0.7261 - val_loss: 1.3113 - val_categorical_accuracy: 0.7542
# Epoch 171/200
# 1/1 [==============================] - 0s 56ms/step - loss: 1.3433 - categorical_accuracy: 0.7269 - val_loss: 1.3078 - val_categorical_accuracy: 0.7550
# Epoch 172/200
# 1/1 [==============================] - 0s 58ms/step - loss: 1.3400 - categorical_accuracy: 0.7274 - val_loss: 1.3044 - val_categorical_accuracy: 0.7558
# Epoch 173/200
# 1/1 [==============================] - 0s 59ms/step - loss: 1.3366 - categorical_accuracy: 0.7279 - val_loss: 1.3010 - val_categorical_accuracy: 0.7563
# Epoch 174/200
# 1/1 [==============================] - 0s 58ms/step - loss: 1.3333 - categorical_accuracy: 0.7286 - val_loss: 1.2977 - val_categorical_accuracy: 0.7574
# Epoch 175/200
# 1/1 [==============================] - 0s 57ms/step - loss: 1.3300 - categorical_accuracy: 0.7291 - val_loss: 1.2943 - val_categorical_accuracy: 0.7580
# Epoch 176/200
# 1/1 [==============================] - 0s 57ms/step - loss: 1.3268 - categorical_accuracy: 0.7296 - val_loss: 1.2910 - val_categorical_accuracy: 0.7588
# Epoch 177/200
# 1/1 [==============================] - 0s 41ms/step - loss: 1.3235 - categorical_accuracy: 0.7305 - val_loss: 1.2877 - val_categorical_accuracy: 0.7597
# Epoch 178/200
# 1/1 [==============================] - 0s 49ms/step - loss: 1.3203 - categorical_accuracy: 0.7312 - val_loss: 1.2844 - val_categorical_accuracy: 0.7605
# Epoch 179/200
# 1/1 [==============================] - 0s 46ms/step - loss: 1.3171 - categorical_accuracy: 0.7320 - val_loss: 1.2812 - val_categorical_accuracy: 0.7614
# Epoch 180/200
# 1/1 [==============================] - 0s 101ms/step - loss: 1.3139 - categorical_accuracy: 0.7325 - val_loss: 1.2779 - val_categorical_accuracy: 0.7618
# Epoch 181/200
# 1/1 [==============================] - 0s 46ms/step - loss: 1.3107 - categorical_accuracy: 0.7332 - val_loss: 1.2747 - val_categorical_accuracy: 0.7624
# Epoch 182/200
# 1/1 [==============================] - 0s 46ms/step - loss: 1.3076 - categorical_accuracy: 0.7339 - val_loss: 1.2715 - val_categorical_accuracy: 0.7626
# Epoch 183/200
# 1/1 [==============================] - 0s 42ms/step - loss: 1.3045 - categorical_accuracy: 0.7345 - val_loss: 1.2683 - val_categorical_accuracy: 0.7630
# Epoch 184/200
# 1/1 [==============================] - 0s 46ms/step - loss: 1.3014 - categorical_accuracy: 0.7350 - val_loss: 1.2652 - val_categorical_accuracy: 0.7634
# Epoch 185/200
# 1/1 [==============================] - 0s 42ms/step - loss: 1.2983 - categorical_accuracy: 0.7354 - val_loss: 1.2621 - val_categorical_accuracy: 0.7638
# Epoch 186/200
# 1/1 [==============================] - 0s 47ms/step - loss: 1.2952 - categorical_accuracy: 0.7361 - val_loss: 1.2589 - val_categorical_accuracy: 0.7645
# Epoch 187/200
# 1/1 [==============================] - 0s 46ms/step - loss: 1.2922 - categorical_accuracy: 0.7368 - val_loss: 1.2559 - val_categorical_accuracy: 0.7649
# Epoch 188/200
# 1/1 [==============================] - 0s 43ms/step - loss: 1.2892 - categorical_accuracy: 0.7374 - val_loss: 1.2528 - val_categorical_accuracy: 0.7656
# Epoch 189/200
# 1/1 [==============================] - 0s 43ms/step - loss: 1.2862 - categorical_accuracy: 0.7380 - val_loss: 1.2497 - val_categorical_accuracy: 0.7657
# Epoch 190/200
# 1/1 [==============================] - 0s 47ms/step - loss: 1.2832 - categorical_accuracy: 0.7386 - val_loss: 1.2467 - val_categorical_accuracy: 0.7663
# Epoch 191/200
# 1/1 [==============================] - 0s 46ms/step - loss: 1.2802 - categorical_accuracy: 0.7390 - val_loss: 1.2437 - val_categorical_accuracy: 0.7667
# Epoch 192/200
# 1/1 [==============================] - 0s 45ms/step - loss: 1.2773 - categorical_accuracy: 0.7398 - val_loss: 1.2407 - val_categorical_accuracy: 0.7671
# Epoch 193/200
# 1/1 [==============================] - 0s 50ms/step - loss: 1.2743 - categorical_accuracy: 0.7404 - val_loss: 1.2377 - val_categorical_accuracy: 0.7677
# Epoch 194/200
# 1/1 [==============================] - 0s 45ms/step - loss: 1.2714 - categorical_accuracy: 0.7410 - val_loss: 1.2347 - val_categorical_accuracy: 0.7681
# Epoch 195/200
# 1/1 [==============================] - 0s 45ms/step - loss: 1.2685 - categorical_accuracy: 0.7416 - val_loss: 1.2318 - val_categorical_accuracy: 0.7684
# Epoch 196/200
# 1/1 [==============================] - 0s 48ms/step - loss: 1.2657 - categorical_accuracy: 0.7421 - val_loss: 1.2289 - val_categorical_accuracy: 0.7687
# Epoch 197/200
# 1/1 [==============================] - 0s 47ms/step - loss: 1.2628 - categorical_accuracy: 0.7429 - val_loss: 1.2260 - val_categorical_accuracy: 0.7693
# Epoch 198/200
# 1/1 [==============================] - 0s 46ms/step - loss: 1.2600 - categorical_accuracy: 0.7434 - val_loss: 1.2231 - val_categorical_accuracy: 0.7699
# Epoch 199/200
# 1/1 [==============================] - 0s 47ms/step - loss: 1.2571 - categorical_accuracy: 0.7440 - val_loss: 1.2202 - val_categorical_accuracy: 0.7702
# Epoch 200/200
# 1/1 [==============================] - 0s 46ms/step - loss: 1.2543 - categorical_accuracy: 0.7446 - val_loss: 1.2174 - val_categorical_accuracy: 0.7707

# %% [markdown]
# ### Testing

# %%
score = model.evaluate(X_test, Y_test, verbose=1)
print("Test score:", score[0])
print('Test accuracy:', score[1])
# Out:
# 313/313 [==============================] - 0s 374us/step - loss: 1.2275 - categorical_accuracy: 0.7573
# Test score: 1.227496862411499
# Test accuracy: 0.7573000192642212

# %% [markdown]
# An accuracy of 92.27% on the test set sounds great, and that this can be achieved using only 7850 parameters - which after all encode all the knowledge about the dataset - is impressive. Yet, misclassifying every tenth digit is of little practical relevance. In fact, even 99.9% would mean that one out of a thousand digits is misread. When using such a network to identify the zip code on a letter, every 200th letter, on average, would be subject to a wrong reading.

# %% [markdown]
# ## Increasing model complexity

# %% [markdown]
# We can increase the complexity of the model by adding hidden layers. For example, adding two hidden layers with 128 neurons each, increases the number of parameters to 118,282. In this case, we can obtain a test accuracy of 97.61%. You can further increase model complexity, for example by employing 1280 hidden nodes, resulting in more than 2.6M parameters. This will allow you to exceed 99% on training accuracy, but not much more than 98% on the test. At some point, you will learn an exact representation of the training data, even 100% accuracy on the training set, but not be able to train a network that is able to truly understand what to look for in your data. This is known as <i>overfitting</i>. As a rule of thumb, a network should always be trained so that the accuracy of training exceeds that of the test set, but not too much further as the reason is likely overfitting.

# %%
NB_EPOCH=200
BATCH_SIZE=128


model = Sequential()
model.add(Dense(128, input_shape=(784,)))
model.add(Activation('relu'))
model.add(Dense(128))
model.add(Activation('relu'))
model.add(Dense(10))
model.add(Activation('softmax'))
model.summary()
model.compile(loss='categorical_crossentropy', optimizer=SGD(), metrics=['categorical_accuracy'])

from keras.utils import plot_model
plot_model(model, show_shapes='true', to_file='figs/model.png')
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 128)               100480
# _________________________________________________________________
# activation_1 (Activation)    (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               16512
# _________________________________________________________________
# activation_2 (Activation)    (None, 128)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                1290
# _________________________________________________________________
# activation_3 (Activation)    (None, 10)                0
# =================================================================
# Total params: 118,282
# Trainable params: 118,282
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# It is also possible to render the neural network graphically using Keras' <code>plot_model</code> module (see above)
#
# <center>
# <img src="figs/model.png" width="30%">
# </center>

# %%
history = model.fit(X_train, Y_train,
batch_size=128, epochs=200,
verbose=1, validation_split=0.2)
score = model.evaluate(X_test, Y_test, verbose=1)
print("Test score:", score[0])
print('Test accuracy:', score[1])
# Out:
# Epoch 1/200
# 375/375 [==============================] - 1s 2ms/step - loss: 1.8836 - categorical_accuracy: 0.4353 - val_loss: 0.7012 - val_categorical_accuracy: 0.8490
# Epoch 2/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.6366 - categorical_accuracy: 0.8480 - val_loss: 0.4378 - val_categorical_accuracy: 0.8876
# Epoch 3/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.4498 - categorical_accuracy: 0.8789 - val_loss: 0.3657 - val_categorical_accuracy: 0.9002
# Epoch 4/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.3827 - categorical_accuracy: 0.8943 - val_loss: 0.3299 - val_categorical_accuracy: 0.9072
# Epoch 5/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.3564 - categorical_accuracy: 0.8987 - val_loss: 0.3062 - val_categorical_accuracy: 0.9144
# Epoch 6/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.3208 - categorical_accuracy: 0.9083 - val_loss: 0.2916 - val_categorical_accuracy: 0.9178
# Epoch 7/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.3062 - categorical_accuracy: 0.9121 - val_loss: 0.2774 - val_categorical_accuracy: 0.9226
# Epoch 8/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.2885 - categorical_accuracy: 0.9174 - val_loss: 0.2655 - val_categorical_accuracy: 0.9260
# Epoch 9/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.2793 - categorical_accuracy: 0.9204 - val_loss: 0.2562 - val_categorical_accuracy: 0.9300
# Epoch 10/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.2609 - categorical_accuracy: 0.9234 - val_loss: 0.2471 - val_categorical_accuracy: 0.9312
# Epoch 11/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.2557 - categorical_accuracy: 0.9270 - val_loss: 0.2404 - val_categorical_accuracy: 0.9338
# Epoch 12/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.2427 - categorical_accuracy: 0.9310 - val_loss: 0.2333 - val_categorical_accuracy: 0.9352
# Epoch 13/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.2375 - categorical_accuracy: 0.9314 - val_loss: 0.2282 - val_categorical_accuracy: 0.9364
# Epoch 14/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.2296 - categorical_accuracy: 0.9336 - val_loss: 0.2206 - val_categorical_accuracy: 0.9395
# Epoch 15/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.2259 - categorical_accuracy: 0.9346 - val_loss: 0.2156 - val_categorical_accuracy: 0.9409
# Epoch 16/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.2151 - categorical_accuracy: 0.9386 - val_loss: 0.2104 - val_categorical_accuracy: 0.9422
# Epoch 17/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.2093 - categorical_accuracy: 0.9407 - val_loss: 0.2059 - val_categorical_accuracy: 0.9432
# Epoch 18/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.2026 - categorical_accuracy: 0.9423 - val_loss: 0.2009 - val_categorical_accuracy: 0.9445
# Epoch 19/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.2008 - categorical_accuracy: 0.9426 - val_loss: 0.1978 - val_categorical_accuracy: 0.9459
# Epoch 20/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.1939 - categorical_accuracy: 0.9449 - val_loss: 0.1925 - val_categorical_accuracy: 0.9475
# Epoch 21/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.1883 - categorical_accuracy: 0.9454 - val_loss: 0.1902 - val_categorical_accuracy: 0.9479
# Epoch 22/200
# 375/375 [==============================] - 1s 1ms/step - loss: 0.1876 - categorical_accuracy: 0.9454 - val_loss: 0.1854 - val_categorical_accuracy: 0.9492
# Epoch 23/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.1770 - categorical_accuracy: 0.9498 - val_loss: 0.1820 - val_categorical_accuracy: 0.9501
# Epoch 24/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.1710 - categorical_accuracy: 0.9512 - val_loss: 0.1785 - val_categorical_accuracy: 0.9507
# Epoch 25/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.1697 - categorical_accuracy: 0.9500 - val_loss: 0.1764 - val_categorical_accuracy: 0.9505
# Epoch 26/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.1661 - categorical_accuracy: 0.9519 - val_loss: 0.1729 - val_categorical_accuracy: 0.9515
# Epoch 27/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.1598 - categorical_accuracy: 0.9542 - val_loss: 0.1699 - val_categorical_accuracy: 0.9522
# Epoch 28/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.1623 - categorical_accuracy: 0.9536 - val_loss: 0.1684 - val_categorical_accuracy: 0.9528
# Epoch 29/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.1518 - categorical_accuracy: 0.9553 - val_loss: 0.1654 - val_categorical_accuracy: 0.9538
# Epoch 30/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.1590 - categorical_accuracy: 0.9546 - val_loss: 0.1635 - val_categorical_accuracy: 0.9538
# Epoch 31/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.1480 - categorical_accuracy: 0.9580 - val_loss: 0.1610 - val_categorical_accuracy: 0.9551
# Epoch 32/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.1419 - categorical_accuracy: 0.9591 - val_loss: 0.1586 - val_categorical_accuracy: 0.9547
# Epoch 33/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.1406 - categorical_accuracy: 0.9598 - val_loss: 0.1564 - val_categorical_accuracy: 0.9559
# Epoch 34/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.1381 - categorical_accuracy: 0.9610 - val_loss: 0.1549 - val_categorical_accuracy: 0.9563
# Epoch 35/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.1350 - categorical_accuracy: 0.9603 - val_loss: 0.1530 - val_categorical_accuracy: 0.9578
# Epoch 36/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.1329 - categorical_accuracy: 0.9618 - val_loss: 0.1500 - val_categorical_accuracy: 0.9579
# Epoch 37/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.1363 - categorical_accuracy: 0.9597 - val_loss: 0.1494 - val_categorical_accuracy: 0.9584
# Epoch 38/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.1323 - categorical_accuracy: 0.9617 - val_loss: 0.1466 - val_categorical_accuracy: 0.9588
# Epoch 39/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.1305 - categorical_accuracy: 0.9620 - val_loss: 0.1462 - val_categorical_accuracy: 0.9585
# Epoch 40/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.1246 - categorical_accuracy: 0.9645 - val_loss: 0.1433 - val_categorical_accuracy: 0.9601
# Epoch 41/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.1207 - categorical_accuracy: 0.9646 - val_loss: 0.1423 - val_categorical_accuracy: 0.9597
# Epoch 42/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.1214 - categorical_accuracy: 0.9653 - val_loss: 0.1415 - val_categorical_accuracy: 0.9607
# Epoch 43/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.1165 - categorical_accuracy: 0.9659 - val_loss: 0.1386 - val_categorical_accuracy: 0.9616
# Epoch 44/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.1136 - categorical_accuracy: 0.9679 - val_loss: 0.1371 - val_categorical_accuracy: 0.9621
# Epoch 45/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.1128 - categorical_accuracy: 0.9683 - val_loss: 0.1357 - val_categorical_accuracy: 0.9622
# Epoch 46/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.1061 - categorical_accuracy: 0.9707 - val_loss: 0.1349 - val_categorical_accuracy: 0.9617
# Epoch 47/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.1087 - categorical_accuracy: 0.9688 - val_loss: 0.1337 - val_categorical_accuracy: 0.9624
# Epoch 48/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.1077 - categorical_accuracy: 0.9696 - val_loss: 0.1319 - val_categorical_accuracy: 0.9641
# Epoch 49/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.1077 - categorical_accuracy: 0.9697 - val_loss: 0.1310 - val_categorical_accuracy: 0.9634
# Epoch 50/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.1029 - categorical_accuracy: 0.9726 - val_loss: 0.1298 - val_categorical_accuracy: 0.9643
# Epoch 51/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.1043 - categorical_accuracy: 0.9708 - val_loss: 0.1290 - val_categorical_accuracy: 0.9635
# Epoch 52/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.0991 - categorical_accuracy: 0.9731 - val_loss: 0.1270 - val_categorical_accuracy: 0.9651
# Epoch 53/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.1031 - categorical_accuracy: 0.9721 - val_loss: 0.1278 - val_categorical_accuracy: 0.9646
# Epoch 54/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.0994 - categorical_accuracy: 0.9723 - val_loss: 0.1247 - val_categorical_accuracy: 0.9648
# Epoch 55/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.0963 - categorical_accuracy: 0.9732 - val_loss: 0.1238 - val_categorical_accuracy: 0.9657
# Epoch 56/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.0952 - categorical_accuracy: 0.9740 - val_loss: 0.1230 - val_categorical_accuracy: 0.9657
# Epoch 57/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.0972 - categorical_accuracy: 0.9740 - val_loss: 0.1234 - val_categorical_accuracy: 0.9657
# Epoch 58/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.0916 - categorical_accuracy: 0.9753 - val_loss: 0.1208 - val_categorical_accuracy: 0.9661
# Epoch 59/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.0893 - categorical_accuracy: 0.9755 - val_loss: 0.1207 - val_categorical_accuracy: 0.9663
# Epoch 60/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.0898 - categorical_accuracy: 0.9754 - val_loss: 0.1196 - val_categorical_accuracy: 0.9668
# Epoch 61/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.0870 - categorical_accuracy: 0.9770 - val_loss: 0.1192 - val_categorical_accuracy: 0.9673
# Epoch 62/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.0844 - categorical_accuracy: 0.9768 - val_loss: 0.1185 - val_categorical_accuracy: 0.9676
# Epoch 63/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.0848 - categorical_accuracy: 0.9769 - val_loss: 0.1178 - val_categorical_accuracy: 0.9678
# Epoch 64/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.0855 - categorical_accuracy: 0.9772 - val_loss: 0.1171 - val_categorical_accuracy: 0.9678
# Epoch 65/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.0836 - categorical_accuracy: 0.9773 - val_loss: 0.1152 - val_categorical_accuracy: 0.9678
# Epoch 66/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.0824 - categorical_accuracy: 0.9773 - val_loss: 0.1146 - val_categorical_accuracy: 0.9682
# Epoch 67/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.0786 - categorical_accuracy: 0.9787 - val_loss: 0.1140 - val_categorical_accuracy: 0.9684
# Epoch 68/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.0793 - categorical_accuracy: 0.9782 - val_loss: 0.1135 - val_categorical_accuracy: 0.9687
# Epoch 69/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.0789 - categorical_accuracy: 0.9796 - val_loss: 0.1127 - val_categorical_accuracy: 0.9687
# Epoch 70/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.0736 - categorical_accuracy: 0.9806 - val_loss: 0.1121 - val_categorical_accuracy: 0.9687
# Epoch 71/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.0767 - categorical_accuracy: 0.9791 - val_loss: 0.1112 - val_categorical_accuracy: 0.9690
# Epoch 72/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.0744 - categorical_accuracy: 0.9799 - val_loss: 0.1110 - val_categorical_accuracy: 0.9688
# Epoch 73/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.0739 - categorical_accuracy: 0.9799 - val_loss: 0.1106 - val_categorical_accuracy: 0.9693
# Epoch 74/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.0725 - categorical_accuracy: 0.9806 - val_loss: 0.1100 - val_categorical_accuracy: 0.9687
# Epoch 75/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.0728 - categorical_accuracy: 0.9798 - val_loss: 0.1093 - val_categorical_accuracy: 0.9695
# Epoch 76/200
# 375/375 [==============================] - 1s 1ms/step - loss: 0.0697 - categorical_accuracy: 0.9813 - val_loss: 0.1090 - val_categorical_accuracy: 0.9693
# Epoch 77/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.0701 - categorical_accuracy: 0.9812 - val_loss: 0.1082 - val_categorical_accuracy: 0.9693
# Epoch 78/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.0694 - categorical_accuracy: 0.9817 - val_loss: 0.1077 - val_categorical_accuracy: 0.9695
# Epoch 79/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.0670 - categorical_accuracy: 0.9819 - val_loss: 0.1070 - val_categorical_accuracy: 0.9695
# Epoch 80/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.0670 - categorical_accuracy: 0.9823 - val_loss: 0.1064 - val_categorical_accuracy: 0.9697
# Epoch 81/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.0658 - categorical_accuracy: 0.9819 - val_loss: 0.1074 - val_categorical_accuracy: 0.9693
# Epoch 82/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.0666 - categorical_accuracy: 0.9821 - val_loss: 0.1054 - val_categorical_accuracy: 0.9707
# Epoch 83/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.0636 - categorical_accuracy: 0.9835 - val_loss: 0.1055 - val_categorical_accuracy: 0.9700
# Epoch 84/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.0623 - categorical_accuracy: 0.9832 - val_loss: 0.1048 - val_categorical_accuracy: 0.9697
# Epoch 85/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.0619 - categorical_accuracy: 0.9832 - val_loss: 0.1040 - val_categorical_accuracy: 0.9711
# Epoch 86/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.0615 - categorical_accuracy: 0.9838 - val_loss: 0.1044 - val_categorical_accuracy: 0.9705
# Epoch 87/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.0607 - categorical_accuracy: 0.9844 - val_loss: 0.1037 - val_categorical_accuracy: 0.9710
# Epoch 88/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.0609 - categorical_accuracy: 0.9830 - val_loss: 0.1035 - val_categorical_accuracy: 0.9711
# Epoch 89/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.0580 - categorical_accuracy: 0.9849 - val_loss: 0.1035 - val_categorical_accuracy: 0.9712
# Epoch 90/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.0570 - categorical_accuracy: 0.9855 - val_loss: 0.1027 - val_categorical_accuracy: 0.9707
# Epoch 91/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.0586 - categorical_accuracy: 0.9851 - val_loss: 0.1029 - val_categorical_accuracy: 0.9707
# Epoch 92/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.0525 - categorical_accuracy: 0.9872 - val_loss: 0.1018 - val_categorical_accuracy: 0.9712
# Epoch 93/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.0563 - categorical_accuracy: 0.9858 - val_loss: 0.1015 - val_categorical_accuracy: 0.9719
# Epoch 94/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.0569 - categorical_accuracy: 0.9855 - val_loss: 0.1015 - val_categorical_accuracy: 0.9710
# Epoch 95/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.0534 - categorical_accuracy: 0.9866 - val_loss: 0.1009 - val_categorical_accuracy: 0.9716
# Epoch 96/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.0527 - categorical_accuracy: 0.9859 - val_loss: 0.1007 - val_categorical_accuracy: 0.9716
# Epoch 97/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.0508 - categorical_accuracy: 0.9877 - val_loss: 0.1007 - val_categorical_accuracy: 0.9714
# Epoch 98/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.0537 - categorical_accuracy: 0.9868 - val_loss: 0.1004 - val_categorical_accuracy: 0.9722
# Epoch 99/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.0522 - categorical_accuracy: 0.9866 - val_loss: 0.1001 - val_categorical_accuracy: 0.9716
# Epoch 100/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.0503 - categorical_accuracy: 0.9875 - val_loss: 0.0994 - val_categorical_accuracy: 0.9718
# Epoch 101/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.0513 - categorical_accuracy: 0.9866 - val_loss: 0.0996 - val_categorical_accuracy: 0.9721
# Epoch 102/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.0510 - categorical_accuracy: 0.9868 - val_loss: 0.0993 - val_categorical_accuracy: 0.9719
# Epoch 103/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.0515 - categorical_accuracy: 0.9870 - val_loss: 0.0995 - val_categorical_accuracy: 0.9720
# Epoch 104/200
#  95/375 [======>.......................] - ETA: 0s - loss: 0.0457 - categorical_accuracy: 0.9885

# %% [markdown]
# Training history is available via Keras' <code>history</code> object. Its a dictionary with the following keys (this depends on how the model was compiled). It is particularly helpful to observe where training and test accuracy start to diverge, which is the point at which further training does not help.

# %%
history.history.keys()
# Out:
# dict_keys(['val_loss', 'val_categorical_accuracy', 'loss', 'categorical_accuracy'])

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['categorical_accuracy'])
plt.plot(history.history['val_categorical_accuracy'])
plt.xlabel('Epochs')
plt.ylabel('Categorical accuracy')
plt.legend(['Training','Test'])

# %% [markdown]
# # Improving network performance (the old way)
#
# We note that all training so far has been done on the raw 28x28 bytes data. Furthermore, the 2D input data has been turned into a column vector leaving it up to the network to cherry-pick the salient information. In classic machine learning this has never been done. Instead, the trick has always been to carefully engineer features that both reduce the amount of data the network has to deal with and integrate human expert knowledge as best as possible.
#
# Looking at the MNIST data, there are many ideas that come to mind. For example, we might use basic image statistics to generate a first set of features. These could be the percentage of the matrix actually covered by pixels (with the numbers 8 and 9 using more pixels than the number 1, e.g.), the "center of mass" of the images with some numbers like 1 and 8 having a center of mass closer to the center and so on.
#
# We can also convolve the image with a Sobel-like filter to detect edges. Finally, we could downsample the image by grouping pixels into groups of 4x4 or even 7x7, and thresholding them. Here, the idea would be that presence of data in the new 16 or 49 "super-pixels" would actually suffice to classify the digits.
#
# Here, we first convolve the image with an edge detection kernel, then downsample it to a 7x7 image.

# %%
from scipy import signal
from skimage.transform import downscale_local_mean # scikit-image

(X_train_orig, y_train), (X_test_orig, y_test) = mnist.load_data()
X_train=np.zeros((60000,7,7))
X_test=np.zeros((10000,7,7))

for I in range(X_train.shape[0]):
    X_train[I]=downscale_local_mean(signal.convolve2d(X_train_orig[I,:,:]/255,[[-1,-1,-1],[-1,-8,-1],[-1,-1,-1]],mode='valid'),(4,4))
    X_train[I]/=X_train[I].min() # values are negative after convolution

for I in range(X_test.shape[0]):
    X_test[I]=downscale_local_mean(signal.convolve2d(X_test_orig[I,:,:]/255,[[-1,-1,-1],[-1,-8,-1],[-1,-1,-1]],mode='valid'),(4,4))
    X_test[I]/=X_test[I].min()

Y_train = np_utils.to_categorical(y_train, 10)
Y_test = np_utils.to_categorical(y_test, 10)

# %%
import matplotlib.pyplot as plt
for I in range(4):
    for J in range(4):
        plt.subplot(4,4,I*4+J+1)
        plt.imshow(X_train[I*4+J,:])
plt.show()

# %%
X_train=X_train.reshape(60000,49) # 7x7
X_test=X_test.reshape(10000,49)

model = Sequential()
model.add(Dense(100, input_shape=(49,)))
model.add(Activation('relu'))
model.add(Dense(10))
model.add(Activation('softmax'))
model.summary()

model.compile(loss='categorical_crossentropy', optimizer=SGD(), metrics=['categorical_accuracy'])

history = model.fit(X_train, Y_train,batch_size=128, epochs=200, verbose=1, validation_split=0.2)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_37 (Dense)             (None, 100)               5000
# _________________________________________________________________
# activation_37 (Activation)   (None, 100)               0
# _________________________________________________________________
# dense_38 (Dense)             (None, 10)                1010
# _________________________________________________________________
# activation_38 (Activation)   (None, 10)                0
# =================================================================
# Total params: 6,010
# Trainable params: 6,010
# Non-trainable params: 0
# _________________________________________________________________
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/200
# 48000/48000 [==============================] - 1s 17us/step - loss: 2.0864 - categorical_accuracy: 0.4040 - val_loss: 1.8903 - val_categorical_accuracy: 0.6118
# Epoch 2/200
# 48000/48000 [==============================] - 0s 9us/step - loss: 1.7164 - categorical_accuracy: 0.6621 - val_loss: 1.5237 - val_categorical_accuracy: 0.7340
# Epoch 3/200
# 48000/48000 [==============================] - 0s 9us/step - loss: 1.3858 - categorical_accuracy: 0.7418 - val_loss: 1.2200 - val_categorical_accuracy: 0.7856
# Epoch 4/200
# 48000/48000 [==============================] - 0s 9us/step - loss: 1.1316 - categorical_accuracy: 0.7783 - val_loss: 1.0033 - val_categorical_accuracy: 0.8095
# Epoch 5/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.9562 - categorical_accuracy: 0.7999 - val_loss: 0.8575 - val_categorical_accuracy: 0.8287
# Epoch 6/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.8376 - categorical_accuracy: 0.8153 - val_loss: 0.7582 - val_categorical_accuracy: 0.8395
# Epoch 7/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.7555 - categorical_accuracy: 0.8250 - val_loss: 0.6887 - val_categorical_accuracy: 0.8478
# Epoch 8/200
# 48000/48000 [==============================] - 0s 9us/step - loss: 0.6964 - categorical_accuracy: 0.8327 - val_loss: 0.6376 - val_categorical_accuracy: 0.8539
# Epoch 9/200
# 48000/48000 [==============================] - 0s 9us/step - loss: 0.6521 - categorical_accuracy: 0.8373 - val_loss: 0.5993 - val_categorical_accuracy: 0.8553
# Epoch 10/200
# 48000/48000 [==============================] - 0s 9us/step - loss: 0.6178 - categorical_accuracy: 0.8415 - val_loss: 0.5685 - val_categorical_accuracy: 0.8600
# Epoch 11/200
# 48000/48000 [==============================] - 0s 9us/step - loss: 0.5904 - categorical_accuracy: 0.8450 - val_loss: 0.5446 - val_categorical_accuracy: 0.8625
# Epoch 12/200
# 48000/48000 [==============================] - 0s 9us/step - loss: 0.5679 - categorical_accuracy: 0.8474 - val_loss: 0.5243 - val_categorical_accuracy: 0.8645
# Epoch 13/200
# 48000/48000 [==============================] - 0s 9us/step - loss: 0.5491 - categorical_accuracy: 0.8505 - val_loss: 0.5072 - val_categorical_accuracy: 0.8685
# Epoch 14/200
# 48000/48000 [==============================] - 0s 9us/step - loss: 0.5331 - categorical_accuracy: 0.8533 - val_loss: 0.4930 - val_categorical_accuracy: 0.8698
# Epoch 15/200
# 48000/48000 [==============================] - 0s 9us/step - loss: 0.5194 - categorical_accuracy: 0.8545 - val_loss: 0.4805 - val_categorical_accuracy: 0.8706
# Epoch 16/200
# 48000/48000 [==============================] - 0s 9us/step - loss: 0.5072 - categorical_accuracy: 0.8569 - val_loss: 0.4695 - val_categorical_accuracy: 0.8733
# Epoch 17/200
# 48000/48000 [==============================] - 0s 9us/step - loss: 0.4966 - categorical_accuracy: 0.8594 - val_loss: 0.4600 - val_categorical_accuracy: 0.8748
# Epoch 18/200
# 48000/48000 [==============================] - 0s 9us/step - loss: 0.4869 - categorical_accuracy: 0.8608 - val_loss: 0.4510 - val_categorical_accuracy: 0.8757
# Epoch 19/200
# 48000/48000 [==============================] - 0s 9us/step - loss: 0.4783 - categorical_accuracy: 0.8626 - val_loss: 0.4435 - val_categorical_accuracy: 0.8759
# Epoch 20/200
# 48000/48000 [==============================] - 0s 9us/step - loss: 0.4705 - categorical_accuracy: 0.8640 - val_loss: 0.4362 - val_categorical_accuracy: 0.8775
# Epoch 21/200
# 48000/48000 [==============================] - 0s 9us/step - loss: 0.4632 - categorical_accuracy: 0.8655 - val_loss: 0.4296 - val_categorical_accuracy: 0.8791
# Epoch 22/200
# 48000/48000 [==============================] - 0s 9us/step - loss: 0.4565 - categorical_accuracy: 0.8673 - val_loss: 0.4237 - val_categorical_accuracy: 0.8793
# Epoch 23/200
# 48000/48000 [==============================] - 0s 9us/step - loss: 0.4503 - categorical_accuracy: 0.8691 - val_loss: 0.4181 - val_categorical_accuracy: 0.8807
# Epoch 24/200
# 48000/48000 [==============================] - 0s 9us/step - loss: 0.4445 - categorical_accuracy: 0.8702 - val_loss: 0.4131 - val_categorical_accuracy: 0.8840
# Epoch 25/200
# 48000/48000 [==============================] - 0s 9us/step - loss: 0.4390 - categorical_accuracy: 0.8715 - val_loss: 0.4081 - val_categorical_accuracy: 0.8846
# Epoch 26/200
# 48000/48000 [==============================] - 0s 9us/step - loss: 0.4339 - categorical_accuracy: 0.8725 - val_loss: 0.4034 - val_categorical_accuracy: 0.8855
# Epoch 27/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.4291 - categorical_accuracy: 0.8735 - val_loss: 0.3992 - val_categorical_accuracy: 0.8871
# Epoch 28/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.4245 - categorical_accuracy: 0.8748 - val_loss: 0.3949 - val_categorical_accuracy: 0.8877
# Epoch 29/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.4201 - categorical_accuracy: 0.8757 - val_loss: 0.3911 - val_categorical_accuracy: 0.8885
# Epoch 30/200
# 48000/48000 [==============================] - 0s 9us/step - loss: 0.4159 - categorical_accuracy: 0.8765 - val_loss: 0.3874 - val_categorical_accuracy: 0.8902
# Epoch 31/200
# 48000/48000 [==============================] - 0s 9us/step - loss: 0.4119 - categorical_accuracy: 0.8778 - val_loss: 0.3840 - val_categorical_accuracy: 0.8905
# Epoch 32/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.4082 - categorical_accuracy: 0.8793 - val_loss: 0.3806 - val_categorical_accuracy: 0.8918
# Epoch 33/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.4045 - categorical_accuracy: 0.8796 - val_loss: 0.3774 - val_categorical_accuracy: 0.8929
# Epoch 34/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.4009 - categorical_accuracy: 0.8807 - val_loss: 0.3741 - val_categorical_accuracy: 0.8935
# Epoch 35/200
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.3976 - categorical_accuracy: 0.8813 - val_loss: 0.3712 - val_categorical_accuracy: 0.8940
# Epoch 36/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.3943 - categorical_accuracy: 0.8827 - val_loss: 0.3680 - val_categorical_accuracy: 0.8940
# Epoch 37/200
# 48000/48000 [==============================] - 0s 9us/step - loss: 0.3911 - categorical_accuracy: 0.8833 - val_loss: 0.3652 - val_categorical_accuracy: 0.8949
# Epoch 38/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.3881 - categorical_accuracy: 0.8841 - val_loss: 0.3628 - val_categorical_accuracy: 0.8952
# Epoch 39/200
# 48000/48000 [==============================] - 0s 9us/step - loss: 0.3851 - categorical_accuracy: 0.8845 - val_loss: 0.3597 - val_categorical_accuracy: 0.8965
# Epoch 40/200
# 48000/48000 [==============================] - 0s 9us/step - loss: 0.3822 - categorical_accuracy: 0.8855 - val_loss: 0.3574 - val_categorical_accuracy: 0.8973
# Epoch 41/200
# 48000/48000 [==============================] - 0s 9us/step - loss: 0.3794 - categorical_accuracy: 0.8861 - val_loss: 0.3551 - val_categorical_accuracy: 0.8974
# Epoch 42/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.3768 - categorical_accuracy: 0.8869 - val_loss: 0.3523 - val_categorical_accuracy: 0.8990
# Epoch 43/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.3741 - categorical_accuracy: 0.8873 - val_loss: 0.3500 - val_categorical_accuracy: 0.8992
# Epoch 44/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.3715 - categorical_accuracy: 0.8880 - val_loss: 0.3477 - val_categorical_accuracy: 0.9000
# Epoch 45/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.3691 - categorical_accuracy: 0.8889 - val_loss: 0.3455 - val_categorical_accuracy: 0.8996
# Epoch 46/200
# 48000/48000 [==============================] - 0s 9us/step - loss: 0.3666 - categorical_accuracy: 0.8898 - val_loss: 0.3437 - val_categorical_accuracy: 0.9002
# Epoch 47/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.3643 - categorical_accuracy: 0.8903 - val_loss: 0.3414 - val_categorical_accuracy: 0.9008
# Epoch 48/200
# 48000/48000 [==============================] - 0s 9us/step - loss: 0.3619 - categorical_accuracy: 0.8911 - val_loss: 0.3393 - val_categorical_accuracy: 0.9017
# Epoch 49/200
# 48000/48000 [==============================] - 0s 9us/step - loss: 0.3597 - categorical_accuracy: 0.8915 - val_loss: 0.3373 - val_categorical_accuracy: 0.9023
# Epoch 50/200
# 48000/48000 [==============================] - 0s 9us/step - loss: 0.3575 - categorical_accuracy: 0.8918 - val_loss: 0.3352 - val_categorical_accuracy: 0.9032
# Epoch 51/200
# 48000/48000 [==============================] - 0s 9us/step - loss: 0.3553 - categorical_accuracy: 0.8930 - val_loss: 0.3333 - val_categorical_accuracy: 0.9033
# Epoch 52/200
# 48000/48000 [==============================] - 0s 9us/step - loss: 0.3533 - categorical_accuracy: 0.8932 - val_loss: 0.3315 - val_categorical_accuracy: 0.9038
# Epoch 53/200
# 48000/48000 [==============================] - 0s 9us/step - loss: 0.3513 - categorical_accuracy: 0.8938 - val_loss: 0.3298 - val_categorical_accuracy: 0.9041
# Epoch 54/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.3493 - categorical_accuracy: 0.8943 - val_loss: 0.3279 - val_categorical_accuracy: 0.9046
# Epoch 55/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.3473 - categorical_accuracy: 0.8950 - val_loss: 0.3263 - val_categorical_accuracy: 0.9056
# Epoch 56/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.3455 - categorical_accuracy: 0.8959 - val_loss: 0.3246 - val_categorical_accuracy: 0.9061
# Epoch 57/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.3436 - categorical_accuracy: 0.8962 - val_loss: 0.3232 - val_categorical_accuracy: 0.9057
# Epoch 58/200
# 48000/48000 [==============================] - 0s 9us/step - loss: 0.3418 - categorical_accuracy: 0.8963 - val_loss: 0.3214 - val_categorical_accuracy: 0.9067
# Epoch 59/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.3401 - categorical_accuracy: 0.8971 - val_loss: 0.3198 - val_categorical_accuracy: 0.9077
# Epoch 60/200
# 48000/48000 [==============================] - 0s 9us/step - loss: 0.3383 - categorical_accuracy: 0.8979 - val_loss: 0.3184 - val_categorical_accuracy: 0.9086
# Epoch 61/200
# 48000/48000 [==============================] - 0s 9us/step - loss: 0.3366 - categorical_accuracy: 0.8982 - val_loss: 0.3169 - val_categorical_accuracy: 0.9080
# Epoch 62/200
# 48000/48000 [==============================] - 0s 9us/step - loss: 0.3349 - categorical_accuracy: 0.8987 - val_loss: 0.3153 - val_categorical_accuracy: 0.9088
# Epoch 63/200
# 48000/48000 [==============================] - 0s 9us/step - loss: 0.3333 - categorical_accuracy: 0.8997 - val_loss: 0.3139 - val_categorical_accuracy: 0.9097
# Epoch 64/200
# 48000/48000 [==============================] - 0s 9us/step - loss: 0.3317 - categorical_accuracy: 0.8994 - val_loss: 0.3125 - val_categorical_accuracy: 0.9101
# Epoch 65/200
# 48000/48000 [==============================] - 0s 9us/step - loss: 0.3301 - categorical_accuracy: 0.9004 - val_loss: 0.3111 - val_categorical_accuracy: 0.9106
# Epoch 66/200
# 48000/48000 [==============================] - 0s 9us/step - loss: 0.3285 - categorical_accuracy: 0.9010 - val_loss: 0.3097 - val_categorical_accuracy: 0.9103
# Epoch 67/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.3269 - categorical_accuracy: 0.9015 - val_loss: 0.3083 - val_categorical_accuracy: 0.9107
# Epoch 68/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.3255 - categorical_accuracy: 0.9010 - val_loss: 0.3070 - val_categorical_accuracy: 0.9110
# Epoch 69/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.3240 - categorical_accuracy: 0.9022 - val_loss: 0.3057 - val_categorical_accuracy: 0.9121
# Epoch 70/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.3225 - categorical_accuracy: 0.9025 - val_loss: 0.3046 - val_categorical_accuracy: 0.9121
# Epoch 71/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.3210 - categorical_accuracy: 0.9032 - val_loss: 0.3031 - val_categorical_accuracy: 0.9122
# Epoch 72/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.3197 - categorical_accuracy: 0.9035 - val_loss: 0.3019 - val_categorical_accuracy: 0.9123
# Epoch 73/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.3182 - categorical_accuracy: 0.9035 - val_loss: 0.3008 - val_categorical_accuracy: 0.9127
# Epoch 74/200
# 48000/48000 [==============================] - 0s 9us/step - loss: 0.3170 - categorical_accuracy: 0.9042 - val_loss: 0.2996 - val_categorical_accuracy: 0.9127
# Epoch 75/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.3155 - categorical_accuracy: 0.9044 - val_loss: 0.2983 - val_categorical_accuracy: 0.9135
# Epoch 76/200
# 48000/48000 [==============================] - 0s 9us/step - loss: 0.3142 - categorical_accuracy: 0.9049 - val_loss: 0.2972 - val_categorical_accuracy: 0.9138
# Epoch 77/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.3129 - categorical_accuracy: 0.9053 - val_loss: 0.2961 - val_categorical_accuracy: 0.9144
# Epoch 78/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.3116 - categorical_accuracy: 0.9056 - val_loss: 0.2951 - val_categorical_accuracy: 0.9140
# Epoch 79/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.3104 - categorical_accuracy: 0.9056 - val_loss: 0.2939 - val_categorical_accuracy: 0.9143
# Epoch 80/200
# 48000/48000 [==============================] - 0s 9us/step - loss: 0.3092 - categorical_accuracy: 0.9065 - val_loss: 0.2928 - val_categorical_accuracy: 0.9152
# Epoch 81/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.3079 - categorical_accuracy: 0.9066 - val_loss: 0.2918 - val_categorical_accuracy: 0.9148
# Epoch 82/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.3067 - categorical_accuracy: 0.9070 - val_loss: 0.2905 - val_categorical_accuracy: 0.9153
# Epoch 83/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.3055 - categorical_accuracy: 0.9072 - val_loss: 0.2896 - val_categorical_accuracy: 0.9163
# Epoch 84/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.3043 - categorical_accuracy: 0.9077 - val_loss: 0.2885 - val_categorical_accuracy: 0.9161
# Epoch 85/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.3032 - categorical_accuracy: 0.9078 - val_loss: 0.2874 - val_categorical_accuracy: 0.9163
# Epoch 86/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.3020 - categorical_accuracy: 0.9081 - val_loss: 0.2866 - val_categorical_accuracy: 0.9167
# Epoch 87/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.3009 - categorical_accuracy: 0.9085 - val_loss: 0.2853 - val_categorical_accuracy: 0.9168
# Epoch 88/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.2997 - categorical_accuracy: 0.9089 - val_loss: 0.2844 - val_categorical_accuracy: 0.9168
# Epoch 89/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.2986 - categorical_accuracy: 0.9090 - val_loss: 0.2834 - val_categorical_accuracy: 0.9175
# Epoch 90/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.2976 - categorical_accuracy: 0.9093 - val_loss: 0.2824 - val_categorical_accuracy: 0.9174
# Epoch 91/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.2965 - categorical_accuracy: 0.9095 - val_loss: 0.2814 - val_categorical_accuracy: 0.9177
# Epoch 92/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.2954 - categorical_accuracy: 0.9097 - val_loss: 0.2807 - val_categorical_accuracy: 0.9170
# Epoch 93/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.2943 - categorical_accuracy: 0.9097 - val_loss: 0.2795 - val_categorical_accuracy: 0.9177
# Epoch 94/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.2932 - categorical_accuracy: 0.9107 - val_loss: 0.2786 - val_categorical_accuracy: 0.9177
# Epoch 95/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.2922 - categorical_accuracy: 0.9108 - val_loss: 0.2777 - val_categorical_accuracy: 0.9176
# Epoch 96/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.2912 - categorical_accuracy: 0.9111 - val_loss: 0.2768 - val_categorical_accuracy: 0.9188
# Epoch 97/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.2901 - categorical_accuracy: 0.9112 - val_loss: 0.2762 - val_categorical_accuracy: 0.9184
# Epoch 98/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.2891 - categorical_accuracy: 0.9120 - val_loss: 0.2750 - val_categorical_accuracy: 0.9191
# Epoch 99/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.2881 - categorical_accuracy: 0.9118 - val_loss: 0.2742 - val_categorical_accuracy: 0.9182
# Epoch 100/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.2871 - categorical_accuracy: 0.9126 - val_loss: 0.2736 - val_categorical_accuracy: 0.9195
# Epoch 101/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.2861 - categorical_accuracy: 0.9129 - val_loss: 0.2724 - val_categorical_accuracy: 0.9208
# Epoch 102/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.2851 - categorical_accuracy: 0.9130 - val_loss: 0.2716 - val_categorical_accuracy: 0.9200
# Epoch 103/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.2842 - categorical_accuracy: 0.9132 - val_loss: 0.2707 - val_categorical_accuracy: 0.9204
# Epoch 104/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.2832 - categorical_accuracy: 0.9141 - val_loss: 0.2700 - val_categorical_accuracy: 0.9207
# Epoch 105/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.2823 - categorical_accuracy: 0.9140 - val_loss: 0.2689 - val_categorical_accuracy: 0.9206
# Epoch 106/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.2813 - categorical_accuracy: 0.9142 - val_loss: 0.2684 - val_categorical_accuracy: 0.9205
# Epoch 107/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.2804 - categorical_accuracy: 0.9145 - val_loss: 0.2675 - val_categorical_accuracy: 0.9214
# Epoch 108/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.2795 - categorical_accuracy: 0.9148 - val_loss: 0.2666 - val_categorical_accuracy: 0.9206
# Epoch 109/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.2785 - categorical_accuracy: 0.9148 - val_loss: 0.2658 - val_categorical_accuracy: 0.9212
# Epoch 110/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.2777 - categorical_accuracy: 0.9156 - val_loss: 0.2651 - val_categorical_accuracy: 0.9221
# Epoch 111/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.2768 - categorical_accuracy: 0.9156 - val_loss: 0.2642 - val_categorical_accuracy: 0.9217
# Epoch 112/200
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.2759 - categorical_accuracy: 0.9164 - val_loss: 0.2634 - val_categorical_accuracy: 0.9224
# Epoch 113/200
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.2749 - categorical_accuracy: 0.9158 - val_loss: 0.2627 - val_categorical_accuracy: 0.9231
# Epoch 114/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.2741 - categorical_accuracy: 0.9167 - val_loss: 0.2620 - val_categorical_accuracy: 0.9239
# Epoch 115/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.2733 - categorical_accuracy: 0.9168 - val_loss: 0.2611 - val_categorical_accuracy: 0.9229
# Epoch 116/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.2724 - categorical_accuracy: 0.9168 - val_loss: 0.2605 - val_categorical_accuracy: 0.9236
# Epoch 117/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.2716 - categorical_accuracy: 0.9173 - val_loss: 0.2597 - val_categorical_accuracy: 0.9242
# Epoch 118/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.2707 - categorical_accuracy: 0.9176 - val_loss: 0.2592 - val_categorical_accuracy: 0.9237
# Epoch 119/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.2699 - categorical_accuracy: 0.9182 - val_loss: 0.2582 - val_categorical_accuracy: 0.9232
# Epoch 120/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.2691 - categorical_accuracy: 0.9183 - val_loss: 0.2575 - val_categorical_accuracy: 0.9244
# Epoch 121/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.2682 - categorical_accuracy: 0.9188 - val_loss: 0.2571 - val_categorical_accuracy: 0.9247
# Epoch 122/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.2675 - categorical_accuracy: 0.9188 - val_loss: 0.2561 - val_categorical_accuracy: 0.9244
# Epoch 123/200
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.2666 - categorical_accuracy: 0.9192 - val_loss: 0.2554 - val_categorical_accuracy: 0.9250
# Epoch 124/200
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.2658 - categorical_accuracy: 0.9194 - val_loss: 0.2547 - val_categorical_accuracy: 0.9252
# Epoch 125/200
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.2650 - categorical_accuracy: 0.9202 - val_loss: 0.2543 - val_categorical_accuracy: 0.9249
# Epoch 126/200
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.2642 - categorical_accuracy: 0.9199 - val_loss: 0.2534 - val_categorical_accuracy: 0.9254
# Epoch 127/200
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.2634 - categorical_accuracy: 0.9201 - val_loss: 0.2526 - val_categorical_accuracy: 0.9248
# Epoch 128/200
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.2626 - categorical_accuracy: 0.9203 - val_loss: 0.2520 - val_categorical_accuracy: 0.9256
# Epoch 129/200
# 48000/48000 [==============================] - 1s 10us/step - loss: 0.2619 - categorical_accuracy: 0.9203 - val_loss: 0.2516 - val_categorical_accuracy: 0.9253
# Epoch 130/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.2611 - categorical_accuracy: 0.9204 - val_loss: 0.2506 - val_categorical_accuracy: 0.9265
# Epoch 131/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.2603 - categorical_accuracy: 0.9210 - val_loss: 0.2501 - val_categorical_accuracy: 0.9254
# Epoch 132/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.2596 - categorical_accuracy: 0.9212 - val_loss: 0.2495 - val_categorical_accuracy: 0.9264
# Epoch 133/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.2588 - categorical_accuracy: 0.9218 - val_loss: 0.2489 - val_categorical_accuracy: 0.9263
# Epoch 134/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.2581 - categorical_accuracy: 0.9215 - val_loss: 0.2481 - val_categorical_accuracy: 0.9269
# Epoch 135/200
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.2573 - categorical_accuracy: 0.9221 - val_loss: 0.2475 - val_categorical_accuracy: 0.9272
# Epoch 136/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.2566 - categorical_accuracy: 0.9221 - val_loss: 0.2468 - val_categorical_accuracy: 0.9276
# Epoch 137/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.2559 - categorical_accuracy: 0.9223 - val_loss: 0.2465 - val_categorical_accuracy: 0.9273
# Epoch 138/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.2551 - categorical_accuracy: 0.9224 - val_loss: 0.2457 - val_categorical_accuracy: 0.9280
# Epoch 139/200
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.2544 - categorical_accuracy: 0.9224 - val_loss: 0.2452 - val_categorical_accuracy: 0.9279
# Epoch 140/200
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.2537 - categorical_accuracy: 0.9226 - val_loss: 0.2448 - val_categorical_accuracy: 0.9277
# Epoch 141/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.2530 - categorical_accuracy: 0.9227 - val_loss: 0.2441 - val_categorical_accuracy: 0.9277
# Epoch 142/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.2523 - categorical_accuracy: 0.9232 - val_loss: 0.2434 - val_categorical_accuracy: 0.9284
# Epoch 143/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.2516 - categorical_accuracy: 0.9234 - val_loss: 0.2428 - val_categorical_accuracy: 0.9283
# Epoch 144/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.2509 - categorical_accuracy: 0.9234 - val_loss: 0.2419 - val_categorical_accuracy: 0.9297
# Epoch 145/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.2502 - categorical_accuracy: 0.9234 - val_loss: 0.2415 - val_categorical_accuracy: 0.9293
# Epoch 146/200
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.2496 - categorical_accuracy: 0.9234 - val_loss: 0.2408 - val_categorical_accuracy: 0.9293
# Epoch 147/200
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.2488 - categorical_accuracy: 0.9242 - val_loss: 0.2404 - val_categorical_accuracy: 0.9298
# Epoch 148/200
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.2482 - categorical_accuracy: 0.9240 - val_loss: 0.2397 - val_categorical_accuracy: 0.9297
# Epoch 149/200
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.2475 - categorical_accuracy: 0.9240 - val_loss: 0.2391 - val_categorical_accuracy: 0.9296
# Epoch 150/200
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.2469 - categorical_accuracy: 0.9248 - val_loss: 0.2388 - val_categorical_accuracy: 0.9300
# Epoch 151/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.2462 - categorical_accuracy: 0.9245 - val_loss: 0.2381 - val_categorical_accuracy: 0.9300
# Epoch 152/200
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.2456 - categorical_accuracy: 0.9248 - val_loss: 0.2375 - val_categorical_accuracy: 0.9304
# Epoch 153/200
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.2449 - categorical_accuracy: 0.9248 - val_loss: 0.2370 - val_categorical_accuracy: 0.9304
# Epoch 154/200
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.2442 - categorical_accuracy: 0.9253 - val_loss: 0.2370 - val_categorical_accuracy: 0.9297
# Epoch 155/200
# 48000/48000 [==============================] - 1s 10us/step - loss: 0.2436 - categorical_accuracy: 0.9252 - val_loss: 0.2359 - val_categorical_accuracy: 0.9312
# Epoch 156/200
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.2430 - categorical_accuracy: 0.9256 - val_loss: 0.2355 - val_categorical_accuracy: 0.9310
# Epoch 157/200
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.2424 - categorical_accuracy: 0.9259 - val_loss: 0.2350 - val_categorical_accuracy: 0.9306
# Epoch 158/200
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.2418 - categorical_accuracy: 0.9258 - val_loss: 0.2343 - val_categorical_accuracy: 0.9316
# Epoch 159/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.2412 - categorical_accuracy: 0.9263 - val_loss: 0.2338 - val_categorical_accuracy: 0.9314
# Epoch 160/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.2405 - categorical_accuracy: 0.9263 - val_loss: 0.2333 - val_categorical_accuracy: 0.9312
# Epoch 161/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.2400 - categorical_accuracy: 0.9259 - val_loss: 0.2327 - val_categorical_accuracy: 0.9319
# Epoch 162/200
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.2393 - categorical_accuracy: 0.9269 - val_loss: 0.2323 - val_categorical_accuracy: 0.9320
# Epoch 163/200
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.2387 - categorical_accuracy: 0.9267 - val_loss: 0.2318 - val_categorical_accuracy: 0.9322
# Epoch 164/200
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.2381 - categorical_accuracy: 0.9269 - val_loss: 0.2313 - val_categorical_accuracy: 0.9319
# Epoch 165/200
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.2375 - categorical_accuracy: 0.9273 - val_loss: 0.2307 - val_categorical_accuracy: 0.9322
# Epoch 166/200
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.2370 - categorical_accuracy: 0.9272 - val_loss: 0.2302 - val_categorical_accuracy: 0.9328
# Epoch 167/200
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.2363 - categorical_accuracy: 0.9275 - val_loss: 0.2300 - val_categorical_accuracy: 0.9325
# Epoch 168/200
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.2359 - categorical_accuracy: 0.9274 - val_loss: 0.2292 - val_categorical_accuracy: 0.9328
# Epoch 169/200
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.2352 - categorical_accuracy: 0.9278 - val_loss: 0.2288 - val_categorical_accuracy: 0.9334
# Epoch 170/200
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.2346 - categorical_accuracy: 0.9278 - val_loss: 0.2282 - val_categorical_accuracy: 0.9329
# Epoch 171/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.2341 - categorical_accuracy: 0.9283 - val_loss: 0.2278 - val_categorical_accuracy: 0.9332
# Epoch 172/200
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.2335 - categorical_accuracy: 0.9280 - val_loss: 0.2273 - val_categorical_accuracy: 0.9336
# Epoch 173/200
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.2329 - categorical_accuracy: 0.9284 - val_loss: 0.2268 - val_categorical_accuracy: 0.9337
# Epoch 174/200
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.2324 - categorical_accuracy: 0.9289 - val_loss: 0.2264 - val_categorical_accuracy: 0.9339
# Epoch 175/200
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.2318 - categorical_accuracy: 0.9288 - val_loss: 0.2259 - val_categorical_accuracy: 0.9343
# Epoch 176/200
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.2314 - categorical_accuracy: 0.9292 - val_loss: 0.2254 - val_categorical_accuracy: 0.9343
# Epoch 177/200
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.2308 - categorical_accuracy: 0.9289 - val_loss: 0.2250 - val_categorical_accuracy: 0.9343
# Epoch 178/200
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.2302 - categorical_accuracy: 0.9295 - val_loss: 0.2246 - val_categorical_accuracy: 0.9340
# Epoch 179/200
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.2297 - categorical_accuracy: 0.9294 - val_loss: 0.2243 - val_categorical_accuracy: 0.9343
# Epoch 180/200
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.2292 - categorical_accuracy: 0.9296 - val_loss: 0.2237 - val_categorical_accuracy: 0.9344
# Epoch 181/200
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.2286 - categorical_accuracy: 0.9298 - val_loss: 0.2232 - val_categorical_accuracy: 0.9348
# Epoch 182/200
# 48000/48000 [==============================] - 1s 14us/step - loss: 0.2281 - categorical_accuracy: 0.9300 - val_loss: 0.2228 - val_categorical_accuracy: 0.9348
# Epoch 183/200
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.2276 - categorical_accuracy: 0.9304 - val_loss: 0.2222 - val_categorical_accuracy: 0.9352
# Epoch 184/200
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.2271 - categorical_accuracy: 0.9307 - val_loss: 0.2220 - val_categorical_accuracy: 0.9349
# Epoch 185/200
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.2266 - categorical_accuracy: 0.9303 - val_loss: 0.2214 - val_categorical_accuracy: 0.9354
# Epoch 186/200
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.2260 - categorical_accuracy: 0.9305 - val_loss: 0.2211 - val_categorical_accuracy: 0.9358
# Epoch 187/200
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.2255 - categorical_accuracy: 0.9311 - val_loss: 0.2205 - val_categorical_accuracy: 0.9353
# Epoch 188/200
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.2250 - categorical_accuracy: 0.9311 - val_loss: 0.2201 - val_categorical_accuracy: 0.9361
# Epoch 189/200
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.2244 - categorical_accuracy: 0.9311 - val_loss: 0.2201 - val_categorical_accuracy: 0.9362
# Epoch 190/200
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.2240 - categorical_accuracy: 0.9314 - val_loss: 0.2193 - val_categorical_accuracy: 0.9358
# Epoch 191/200
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.2235 - categorical_accuracy: 0.9316 - val_loss: 0.2189 - val_categorical_accuracy: 0.9362
# Epoch 192/200
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.2230 - categorical_accuracy: 0.9318 - val_loss: 0.2186 - val_categorical_accuracy: 0.9359
# Epoch 193/200
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.2225 - categorical_accuracy: 0.9320 - val_loss: 0.2183 - val_categorical_accuracy: 0.9358
# Epoch 194/200
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.2221 - categorical_accuracy: 0.9319 - val_loss: 0.2178 - val_categorical_accuracy: 0.9363
# Epoch 195/200
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.2216 - categorical_accuracy: 0.9320 - val_loss: 0.2173 - val_categorical_accuracy: 0.9363
# Epoch 196/200
# 48000/48000 [==============================] - 1s 10us/step - loss: 0.2211 - categorical_accuracy: 0.9322 - val_loss: 0.2169 - val_categorical_accuracy: 0.9371
# Epoch 197/200
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.2206 - categorical_accuracy: 0.9324 - val_loss: 0.2168 - val_categorical_accuracy: 0.9371
# Epoch 198/200
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.2201 - categorical_accuracy: 0.9325 - val_loss: 0.2161 - val_categorical_accuracy: 0.9367
# Epoch 199/200
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.2197 - categorical_accuracy: 0.9324 - val_loss: 0.2157 - val_categorical_accuracy: 0.9367
# Epoch 200/200
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.2192 - categorical_accuracy: 0.9330 - val_loss: 0.2154 - val_categorical_accuracy: 0.9377

# %%
score = model.evaluate(X_test, Y_test, verbose=1)
print("Test score:", score[0])
print('Test accuracy:', score[1])
# Out:
# 10000/10000 [==============================] - 0s 13us/step
# Test score: 0.21038885685503483
# Test accuracy: 0.9357

# %% [markdown]
# This performance is not bad, albeit not as good as our previous attemptes having a deep network find features themselves. To better understand this: when training the network with the full 28x28 pixels, we are letting the network sift through 784 bytes of data to make a decision, which digit an input depicts. In particular, we have no idea what happens inside the network and what it actually ends up looking for. This is different when doing some of the pre-processing ourselves. Specifically, we decided that the majority of the information should be contained in whether a subset of 7x7 "super-pixels" are populated or not. We are then training on the reduced feature set that is represented by only 49 bytes - 16 times less.
#
# Albeit we might be able to hand-engineer better features than those chosen here, even some that are able to ultimately beat a brute-force neural network approach in terms of accuracy, machine learning has developed tools that have made hand-engineering features obsolete, rather take advantage of neural network architectures that in themselves perform preprocessing that are conducive to image and speech recognition. These are known as <i>convolutional neural networks</i>.

# %% [markdown]
# ## Finding optimal training parameters
#
# Albeit poking around with the different options of the variying machine learning toolkits is a lot easier than hand-coding features, and decisions can partly be informed by a fundamental understanding of the underlying methods (such as provided by this course), what works and what does not still heavily depends on the data actually at hand. For example, the "batch size" is a parameter for which only rough guidelines can be given. Often, playing with certain parameters or even systematically sweeping them can provide some intuition. For example, we can easily test the impact of different batch sizes, by training a model with a couple of different ones.

# %%
import time

batch_sizes=[8,16,32,64,128,256,512]
#batch_sizes=[128,256,512]
model = Sequential()
model.add(Dense(NB_CLASSES,input_shape=(784,)))
model.add(Activation('softmax'))
model.compile(loss='categorical_crossentropy', optimizer=OPTIMIZER, metrics=['categorical_accuracy'])

score=np.zeros((len(batch_sizes),2))
times=np.zeros((len(batch_sizes),2))

for I, batch_size in enumerate(batch_sizes):
    t=time.time()
    history = model.fit(X_train, Y_train,batch_size=batch_size, verbose=0, epochs=20, validation_split=VALIDATION_SPLIT)
    score[I] = model.evaluate(X_test, Y_test, verbose=0)
    times[I] = time.time()-t

# %%
plt.plot(batch_sizes,score[:,1])
plt.plot(batch_sizes,score[:,1],'*')
plt.ylabel('Categorical accuracy')
plt.xlabel('Batch size')
plt.show()

plt.plot(batch_sizes,times)
plt.plot(batch_sizes,times,'*')
plt.ylabel('Time [s]')
plt.xlabel('Batch size')
plt.show()

# %% [markdown]
# It is clear from the above experiment, that the batch size actually has an optimum. If too low, the gradient jumps back and forth for every new training instance, if too high, the gradient combines too many experiences into one. We also observe, however, that training becomes much, much slower with smaller batch sizes.

# %% [markdown]
# # Observations
#
# - Coding features by hand as much as possible has been the standard approach to design a machine learning algorithm for many decades. The idea has been that hand-coding leverages as much human expert knowledge as possible, while reducing the data sufficiently to make training a neural network actually tractable.
# - The ability to train also larger networks efficiently, has allowed to create "deep" neural networks that can get very good performance, sometimes even exceeding those of solutions relying on hand-coded features, without much tuning whatsoever.
# - We have introduced a new feature without much ado, using a part of the test set for validation. This can help the training algorithm in many ways, for example detecting overfitting, stopping once a certain performance on valiation is met, and others.
# - Albeit the validation set can help to determine the optimal number of epochs, that is the number of times a dataset is presented to the network, the "batch size" remains a free parameter. If too low, weights are updated for every training instance, which is very susceptive to noise. If too high, the gradient is averaged over too many instances at once, ignoring possibly important information such as particularly salient examples.
# - Overfitting a neural network during training shows that the network is actually capable of modeling the entire dataset. If this is not possible, the network architecture might be too simple to capture the data's non-linearities, requiring additional nodes or layers.
