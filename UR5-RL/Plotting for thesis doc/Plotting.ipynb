# %%
import csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# In /home/scott/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/scott/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/scott/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In /home/scott/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# ...

# %%
roundpeg_standard_rewards=pd.read_csv('rewardlist_roundpeg_withbutton_standardrewards11_02_2021_fullplots.csv')
roundpeg_GRU_rewards=pd.read_csv('rewardlist_cylinder_withbutton_retroactiveVals_GRUrewardsonly_correctedGRUdatascaling_10_26_2021_Fullplots.csv')
squarepeg_standard_rewards=pd.read_csv('rewardlist_squarepeg_withbutton_normalrewardsrun2_10_28_2021.csv')
squarepeg_GRU_rewards=pd.read_csv('rewardlist_squarepeg_withbutton_retroactiveVals_GRUrewardsonly_correctedGRUdatascalingRun2_10_27_2021_fullplots.csv')


roundpeg_PPO_LSTM_lr001_standard_rewards=pd.read_csv('rewardlist_roundpeg_PPO_LSTM_lr0.001_withbutton_standardrewards11_03_2021.csv')
roundpeg_PPO_LSTM_lr0001_standard_rewards=pd.read_csv('rewardlist_roundpeg_PPO_LSTM_lr0.0001_withbutton_standardrewards11_04_2021.csv')

squarepeg_PPO_LSTM_lr001_standard_rewards=pd.read_csv('rewardlist_squarepeg_PPO_LSTM_lr0.001_withbutton_standardrewards11_04_2021.csv')
squarepeg_PPO_LSTM_lr0001_standard_rewards=pd.read_csv('rewardlist_squarepeg_PPO_LSTM_lr0.0001_withbutton_standardrewards11_04_2021.csv')

# %%
squarepeg_GRU_rewards
# Out:
#      Rewardlist  Unnamed: 1  ButtonData  Zposition(Inches)  Zposition(mm)  \
# 0      0.087676    0.087676           0          12.128821     308.072048
# 1      0.542747    0.315212           0          11.963428     303.871080
# 2      0.339343    0.323256           0          12.124521     307.962822
# 3      0.690132    0.414975           0          12.125713     307.993101
# 4      0.293642    0.390708           0          12.131895     308.150130
# ..          ...         ...         ...                ...            ...
# 591    1.000000    0.527423           1          11.895766     302.152469
# 592    0.592631    0.538194           1          11.913037     302.591130
# 593    0.534504    0.549019           0          12.030099     305.564509
# 594    0.184682    0.532613           0          11.975833     304.186151
# 595    0.718970    0.535908           0          12.061868     306.371437
#
#      Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10  \
# ...

# %%
rewardlist_roundpeg_standard_rewards= roundpeg_standard_rewards['Rewardlist'].iloc[0:500].tolist()
rewardlist_rollingavg_roundpeg_standard_rewards= roundpeg_standard_rewards['Unnamed: 1'].iloc[0:500].tolist()
zposition_roundpeg_standard_rewards= roundpeg_standard_rewards['Zposition(mm)'].iloc[0:500].tolist()
zposition_rollingavg_roundpeg_standard_rewards= roundpeg_standard_rewards['Unnamed: 5'].iloc[0:500].tolist()

rewardlist_roundpeg_GRU_rewards= roundpeg_GRU_rewards['Rewardlist'].iloc[0:500].tolist()
rewardlist_rollingavg_roundpeg_GRU_rewards= roundpeg_GRU_rewards['Unnamed: 1'].iloc[0:500].tolist()
zposition_roundpeg_GRU_rewards= roundpeg_GRU_rewards['Zposition(mm)'].iloc[0:500].tolist()
zposition_rollingavg_roundpeg_GRU_rewards= roundpeg_GRU_rewards['Unnamed: 5'].iloc[0:500].tolist()


rewardlist_squarepeg_standard_rewards= squarepeg_standard_rewards['Rewardlist'].iloc[0:500].tolist()
rewardlist_rollingavg_squarepeg_standard_rewards= squarepeg_standard_rewards['Unnamed: 1'].iloc[0:500].tolist()
zposition_squarepeg_standard_rewards= squarepeg_standard_rewards['Zposition(mm)'].iloc[0:500].tolist()
zposition_rollingavg_squarepeg_standard_rewards= squarepeg_standard_rewards['Unnamed: 5'].iloc[0:500].tolist()

rewardlist_squarepeg_squarepeg_GRU_rewards= squarepeg_GRU_rewards['Rewardlist'].iloc[0:500].tolist()
rewardlist_rollingavg_squarepeg_GRU_rewards= squarepeg_GRU_rewards['Unnamed: 1'].iloc[0:500].tolist()
zposition_squarepeg_squarepeg_GRU_rewards= squarepeg_GRU_rewards['Zposition(mm)'].iloc[0:500].tolist()
zposition_rollingavg_squarepeg_GRU_rewards= squarepeg_GRU_rewards['Unnamed: 5'].iloc[0:500].tolist()

rewardlist_roundpeg_PPO_LSTM_lr001_standard_rewards= roundpeg_PPO_LSTM_lr001_standard_rewards['Rewardlist'].iloc[0:500].tolist()
rewardlist_rollingavg_PPO_LSTM_lr001_roundpeg_standard_rewards= roundpeg_PPO_LSTM_lr001_standard_rewards['Unnamed: 1'].iloc[0:500].tolist()
zposition_roundpeg_PPO_LSTM_lr001_standard_rewards= roundpeg_PPO_LSTM_lr001_standard_rewards['Zposition(mm)'].iloc[0:500].tolist()
zposition_rollingavg_PPO_LSTM_lr001_roundpeg_standard_rewards= roundpeg_PPO_LSTM_lr001_standard_rewards['Unnamed: 5'].iloc[0:500].tolist()

rewardlist_roundpeg_PPO_LSTM_lr0001_standard_rewards= roundpeg_PPO_LSTM_lr0001_standard_rewards['Rewardlist'].iloc[0:500].tolist()
rewardlist_rollingavg_PPO_LSTM_lr0001_roundpeg_standard_rewards= roundpeg_PPO_LSTM_lr0001_standard_rewards['Unnamed: 1'].iloc[0:500].tolist()
zposition_roundpeg_PPO_LSTM_lr0001_standard_rewards= roundpeg_PPO_LSTM_lr0001_standard_rewards['Zposition(mm)'].iloc[0:500].tolist()
zposition_rollingavg_PPO_LSTM_lr0001_roundpeg_standard_rewards= roundpeg_PPO_LSTM_lr0001_standard_rewards['Unnamed: 5'].iloc[0:500].tolist()


rewardlist_squarepeg_PPO_LSTM_lr001_standard_rewards= squarepeg_PPO_LSTM_lr001_standard_rewards['Rewardlist'].iloc[0:500].tolist()
rewardlist_rollingavg_PPO_LSTM_lr001_squarepeg_standard_rewards= squarepeg_PPO_LSTM_lr001_standard_rewards['Unnamed: 1'].iloc[0:500].tolist()
zposition_squarepeg_PPO_LSTM_lr001_standard_rewards= squarepeg_PPO_LSTM_lr001_standard_rewards['Zposition(mm)'].iloc[0:500].tolist()
zposition_rollingavg_PPO_LSTM_lr001_squarepeg_standard_rewards= squarepeg_PPO_LSTM_lr001_standard_rewards['Unnamed: 5'].iloc[0:500].tolist()


rewardlist_squarepeg_PPO_LSTM_lr0001_standard_rewards= squarepeg_PPO_LSTM_lr0001_standard_rewards['Rewardlist'].iloc[0:500].tolist()
rewardlist_rollingavg_PPO_LSTM_lr0001_squarepeg_standard_rewards= squarepeg_PPO_LSTM_lr0001_standard_rewards['Unnamed: 1'].iloc[0:500].tolist()
zposition_squarepeg_PPO_LSTM_lr0001_standard_rewards= squarepeg_PPO_LSTM_lr0001_standard_rewards['Zposition(mm)'].iloc[0:500].tolist()
zposition_rollingavg_PPO_LSTM_lr0001_squarepeg_standard_rewards= squarepeg_PPO_LSTM_lr0001_standard_rewards['Unnamed: 5'].iloc[0:500].tolist()

# %%
rewardlabel1='Rewards'
rewardlabel2='Rewards, 50-Ep. Rolling Avg.'

zlabel1='Z-axis Position'
zlabel2='Z-axis Position, 50-Ep. Rolling Avg.'

plt.figure(figsize=(14, 5))
plt.subplot(1, 2, 1)
#plt.scatter([*range(len(rewardlist_roundpeg_standard_rewards))],rewardlist_roundpeg_standard_rewards,label=rewardlabel1)
plt.plot(rewardlist_roundpeg_standard_rewards,label=rewardlabel1)
plt.plot(rewardlist_rollingavg_roundpeg_standard_rewards,label=rewardlabel2, linewidth=3)
plt.legend(loc='lower right')
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.title('Round Peg DQN End-Of-Episode Rewards \n During Training Using Standard Rewards')

plt.subplot(1, 2, 2)
plt.plot(zposition_roundpeg_standard_rewards,label=zlabel1)
plt.plot(zposition_rollingavg_roundpeg_standard_rewards,label=zlabel2, linewidth=3)
plt.legend(loc='upper right')
plt.xlabel('Episode')
plt.ylabel('Z axis position (mm)')
plt.title('Round Peg DQN Final Wrist Z-Axis Positions Per \n Episode During Training Using Standard Rewards')
plt.show()


plt.figure(figsize=(14, 5))
plt.subplot(1, 2, 1)
plt.plot(rewardlist_roundpeg_GRU_rewards,label=rewardlabel1)
plt.plot(rewardlist_rollingavg_roundpeg_GRU_rewards,label=rewardlabel2, linewidth=3)
plt.legend(loc='lower right')
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.title('Round Peg DQN End-Of-Episode Rewards \n During Training Using GRU Rewards')

plt.subplot(1, 2, 2)
plt.plot(zposition_roundpeg_GRU_rewards,label=zlabel1)
plt.plot(zposition_rollingavg_roundpeg_GRU_rewards,label=zlabel2, linewidth=3)
plt.legend(loc='upper right')
plt.xlabel('Episode')
plt.ylabel('Z axis position (mm)')
plt.title('Round Peg DQN Final Wrist Z-Axis Positions Per \n Episode During Training Using GRU Rewards')
plt.show()

# Overlaid Square peg Results:

plt.figure(figsize=(14, 5))
plt.subplot(1, 2, 1)
#plt.plot(rewardlist_squarepeg_standard_rewards,label='Rewards')
plt.plot(rewardlist_rollingavg_roundpeg_standard_rewards,label='Standard Rewards')
#plt.plot(rewardlist_squarepeg_squarepeg_GRU_rewards,label='Rewards')
plt.plot(rewardlist_rollingavg_roundpeg_GRU_rewards,label='GRU Rewards')
plt.legend(loc='lower right')
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.title('Round Peg 50-Episode Rolling Averages of End-Of-Episode Rewards')

plt.subplot(1, 2, 2)
#plt.plot(zposition_squarepeg_standard_rewards,label='End-Of-Episode Z-axis Position')
plt.plot(zposition_rollingavg_roundpeg_standard_rewards,label='Standard Rewards')
#plt.plot(zposition_squarepeg_squarepeg_GRU_rewards,label='End-Of-Episode Z-axis Position')
plt.plot(zposition_rollingavg_roundpeg_GRU_rewards,label='GRU Rewards')

plt.legend(loc='upper right')
plt.xlabel('Episode')
plt.ylabel('Z axis position (mm)')
plt.title('Round Peg 50-Episode Rolling Averages of \n End-Of-Episode Z-Axis Position')
plt.show()


#Square peg---------------------------------


plt.figure(figsize=(14, 5))
plt.subplot(1, 2, 1)
plt.plot(rewardlist_squarepeg_standard_rewards,label=rewardlabel1)
plt.plot(rewardlist_rollingavg_squarepeg_standard_rewards,label=rewardlabel2, linewidth=3)
plt.legend(loc='lower right')
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.title('Square Peg DQN End-Of-Episode Rewards \n During Training Using Standard Rewards')

plt.subplot(1, 2, 2)
plt.plot(zposition_squarepeg_standard_rewards,label=zlabel1)
plt.plot(zposition_rollingavg_squarepeg_standard_rewards,label=zlabel2, linewidth=3)
plt.legend(loc='upper right')
plt.xlabel('Episode')
plt.ylabel('Z axis position (mm)')
plt.title('Square Peg DQN Final Z-Axis Positions Per \n Episode During Training Using Standard Rewards')
plt.show()



plt.figure(figsize=(14, 5))
plt.subplot(1, 2, 1)
plt.plot(rewardlist_squarepeg_squarepeg_GRU_rewards,label=rewardlabel1)
plt.plot(rewardlist_rollingavg_squarepeg_GRU_rewards,label=rewardlabel2, linewidth=3)
plt.ylim([-0.05, 1.05])
plt.legend(loc='lower right')
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.title('Square Peg DQN End-Of-Episode Rewards \n During Training Using GRU Rewards')

plt.subplot(1, 2, 2)
plt.plot(zposition_squarepeg_squarepeg_GRU_rewards,label=zlabel1)
plt.plot(zposition_rollingavg_squarepeg_GRU_rewards,label=zlabel2, linewidth=3)
plt.legend(loc='upper right')
plt.xlabel('Episode')
plt.ylabel('Z axis position (mm)')
plt.title('Square Peg DQN Final Z-Axis Positions Per \n Episode During Training Using GRU Rewards')
plt.show()


# Overlaid Square peg Results:

plt.figure(figsize=(14, 5))
plt.subplot(1, 2, 1)
#plt.plot(rewardlist_squarepeg_standard_rewards,label='Rewards')
plt.plot(rewardlist_rollingavg_squarepeg_standard_rewards,label='Standard Rewards')
#plt.plot(rewardlist_squarepeg_squarepeg_GRU_rewards,label='Rewards')
plt.plot(rewardlist_rollingavg_squarepeg_GRU_rewards,label='GRU Rewards')

plt.legend(loc='lower right')
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.title('Square Peg 50-Episode Rolling Averages of End-Of-Episode Rewards')

plt.subplot(1, 2, 2)
#plt.plot(zposition_squarepeg_standard_rewards,label='End-Of-Episode Z-axis Position')
plt.plot(zposition_rollingavg_squarepeg_standard_rewards,label='Standard Rewards')
#plt.plot(zposition_squarepeg_squarepeg_GRU_rewards,label='End-Of-Episode Z-axis Position')
plt.plot(zposition_rollingavg_squarepeg_GRU_rewards,label='GRU Rewards')

plt.legend(loc='upper right')
plt.xlabel('Episode')
plt.ylabel('Z axis position (mm)')
plt.title('Square Peg  50-Episode Rolling Averages of \n End-Of-Episode Z-Axis Position')
plt.show()



# Overlaid All rolling averages

plt.figure(figsize=(14, 5))
plt.subplot(1, 2, 1)
#plt.plot(rewardlist_squarepeg_standard_rewards,label='Rewards')
plt.plot(rewardlist_rollingavg_roundpeg_standard_rewards,label='Round Peg,Standard Rewards')
#plt.plot(rewardlist_squarepeg_squarepeg_GRU_rewards,label='Rewards')
plt.plot(rewardlist_rollingavg_roundpeg_GRU_rewards,label='Round Peg,GRU Rewards')
plt.plot(rewardlist_rollingavg_squarepeg_standard_rewards,label='Square Peg,Standard Rewards')
#plt.plot(rewardlist_squarepeg_squarepeg_GRU_rewards,label='Rewards')
plt.plot(rewardlist_rollingavg_squarepeg_GRU_rewards,label='Square Peg,GRU Rewards')
plt.legend(loc='lower right')
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.title('Round Peg and Square Peg 50-Episode \n Rolling Averages of End-Of-Episode Rewards')


plt.subplot(1, 2, 2)
#plt.plot(zposition_squarepeg_standard_rewards,label='End-Of-Episode Z-axis Position')
plt.plot(zposition_rollingavg_roundpeg_standard_rewards,label='Round Peg,Standard Rewards')
#plt.plot(zposition_squarepeg_squarepeg_GRU_rewards,label='End-Of-Episode Z-axis Position')
plt.plot(zposition_rollingavg_roundpeg_GRU_rewards,label='Round Peg,GRU Rewards')
plt.plot(zposition_rollingavg_squarepeg_standard_rewards,label='Square Peg,Standard Rewards')
#plt.plot(zposition_squarepeg_squarepeg_GRU_rewards,label='End-Of-Episode Z-axis Position')
plt.plot(zposition_rollingavg_squarepeg_GRU_rewards,label='Square Peg,GRU Rewards')

plt.legend(loc='center right')
plt.xlabel('Episode')
plt.ylabel('Z axis position (mm)')
plt.title('Round Peg and Square Peg 50-Episode Rolling \n Averages of End-Of-Episode Z-Axis Position')
plt.show()

#--PPO LSTM- roundpeg---------------------

plt.figure(figsize=(14, 5))
plt.subplot(1, 2, 1)
#plt.scatter([*range(len(rewardlist_roundpeg_standard_rewards))],rewardlist_roundpeg_standard_rewards,label=rewardlabel1)
plt.plot(rewardlist_roundpeg_PPO_LSTM_lr001_standard_rewards,label=rewardlabel1)
plt.plot(rewardlist_rollingavg_PPO_LSTM_lr001_roundpeg_standard_rewards,label=rewardlabel2, linewidth=3)
plt.legend(loc='lower right')
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.title('Round Peg PPO with LSTM Layers Lr=0.001 \n End-Of-Episode Rewards \n During Training Using Standard Rewards')

plt.subplot(1, 2, 2)
plt.plot(zposition_roundpeg_PPO_LSTM_lr001_standard_rewards,label=zlabel1)
plt.plot(zposition_rollingavg_PPO_LSTM_lr001_roundpeg_standard_rewards,label=zlabel2, linewidth=3)
plt.legend(loc='upper right')
plt.xlabel('Episode')
plt.ylabel('Z axis position (mm)')
plt.title('Round Peg PPO with LSTM Layers Lr=0.001 \n Final Wrist Z-Axis Positions Per \n Episode During Training Using Standard Rewards')
plt.show()


plt.figure(figsize=(14, 5))
plt.subplot(1, 2, 1)
#plt.scatter([*range(len(rewardlist_roundpeg_standard_rewards))],rewardlist_roundpeg_standard_rewards,label=rewardlabel1)
plt.plot(rewardlist_roundpeg_PPO_LSTM_lr0001_standard_rewards,label=rewardlabel1)
plt.plot(rewardlist_rollingavg_PPO_LSTM_lr0001_roundpeg_standard_rewards,label=rewardlabel2, linewidth=3)
plt.legend(loc='lower right')
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.title('Round Peg PPO with LSTM Layers Lr=0.0001 \n End-Of-Episode Rewards \n During Training Using Standard Rewards')

plt.subplot(1, 2, 2)
plt.plot(zposition_roundpeg_PPO_LSTM_lr0001_standard_rewards,label=zlabel1)
plt.plot(zposition_rollingavg_PPO_LSTM_lr0001_roundpeg_standard_rewards,label=zlabel2, linewidth=3)
plt.legend(loc='upper right')
plt.xlabel('Episode')
plt.ylabel('Z axis position (mm)')
plt.title('Round Peg PPO with LSTM Layers Lr=0.0001 \n Final Wrist Z-Axis Positions Per \n Episode During Training Using Standard Rewards')
plt.show()


#--PPO LSTM-COMPARISON- roundpeg--------------------


plt.figure(figsize=(14, 5))
plt.subplot(1, 2, 1)
#plt.plot(rewardlist_squarepeg_standard_rewards,label='Rewards')
plt.plot(rewardlist_rollingavg_roundpeg_standard_rewards,label='Round Peg DQN,Standard Rewards')
#plt.plot(rewardlist_squarepeg_squarepeg_GRU_rewards,label='Rewards')
plt.plot(rewardlist_rollingavg_roundpeg_GRU_rewards,label='Round Peg DQN,GRU Rewards')
plt.plot(rewardlist_rollingavg_PPO_LSTM_lr001_roundpeg_standard_rewards,label='Round Peg,PPO w/ LSTM Layers Lr=0.001  Std. Rwds')
plt.plot(rewardlist_rollingavg_PPO_LSTM_lr0001_roundpeg_standard_rewards,label='Round Peg,PPO w/ LSTM Layers Lr=0.0001  Std. Rwds')
plt.legend(loc='lower right')
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.title('Round Peg DQN vs PPO with LSTM Layers 50-Episode \n Rolling Averages of End-Of-Episode Rewards')


plt.subplot(1, 2, 2)
#plt.plot(zposition_squarepeg_standard_rewards,label='End-Of-Episode Z-axis Position')
plt.plot(zposition_rollingavg_roundpeg_standard_rewards,label='Round Peg, DQN with Standard Rewards')
#plt.plot(zposition_squarepeg_squarepeg_GRU_rewards,label='End-Of-Episode Z-axis Position')
plt.plot(zposition_rollingavg_roundpeg_GRU_rewards,label='Round Peg, DQN with GRU Rewards')
plt.plot(zposition_rollingavg_PPO_LSTM_lr001_roundpeg_standard_rewards,label='Round Peg,PPO w/ LSTM Layers Lr=0.001 Std. Rwds.')
plt.plot(zposition_rollingavg_PPO_LSTM_lr0001_roundpeg_standard_rewards,label='Round Peg,PPO w/ LSTM Layers Lr=0.0001 Std. Rwds.')

plt.legend(loc='upper right')
plt.xlabel('Episode')
plt.ylabel('Z axis position (mm)')
plt.title('Round Peg DQN vs PPO with LSTM Layers \n 50-Episode Rolling \n Averages of End-Of-Episode Z-Axis Position')
plt.show()

#--PPO LSTM- squarepeg---------------------

plt.figure(figsize=(14, 5))
plt.subplot(1, 2, 1)
#plt.scatter([*range(len(rewardlist_roundpeg_standard_rewards))],rewardlist_roundpeg_standard_rewards,label=rewardlabel1)
plt.plot(rewardlist_squarepeg_PPO_LSTM_lr001_standard_rewards,label=rewardlabel1)
plt.plot(rewardlist_rollingavg_PPO_LSTM_lr001_squarepeg_standard_rewards,label=rewardlabel2, linewidth=3)
plt.legend(loc='lower right')
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.title('Square Peg PPO with LSTM Lr=0.001 \n Layers End-Of-Episode Rewards \n During Training Using Standard Rewards')

plt.subplot(1, 2, 2)
plt.plot(zposition_squarepeg_PPO_LSTM_lr001_standard_rewards,label=zlabel1)
plt.plot(zposition_rollingavg_PPO_LSTM_lr001_squarepeg_standard_rewards,label=zlabel2, linewidth=3)
plt.legend(loc='upper right')
plt.xlabel('Episode')
plt.ylabel('Z axis position (mm)')
plt.title('Square Peg PPO with LSTM Layers Lr=0.001 Final Wrist Z-Axis Positions Per \n Episode During Training Using Standard Rewards')
plt.show()


plt.figure(figsize=(14, 5))
plt.subplot(1, 2, 1)
#plt.scatter([*range(len(rewardlist_roundpeg_standard_rewards))],rewardlist_roundpeg_standard_rewards,label=rewardlabel1)
plt.plot(rewardlist_squarepeg_PPO_LSTM_lr0001_standard_rewards,label=rewardlabel1)
plt.plot(rewardlist_rollingavg_PPO_LSTM_lr0001_squarepeg_standard_rewards,label=rewardlabel2, linewidth=3)
plt.legend(loc='lower right')
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.title('Square Peg PPO with LSTM Layers Lr=0.0001 \n  End-Of-Episode Rewards During Training Using Standard Rewards')

plt.subplot(1, 2, 2)
plt.plot(zposition_squarepeg_PPO_LSTM_lr0001_standard_rewards,label=zlabel1)
plt.plot(zposition_rollingavg_PPO_LSTM_lr0001_squarepeg_standard_rewards,label=zlabel2, linewidth=3)
plt.legend(loc='upper right')
plt.xlabel('Episode')
plt.ylabel('Z axis position (mm)')
plt.title('Square Peg PPO with LSTM Layers Lr=0.0001 \n  Final Wrist Z-Axis Positions Per \n Episode During Training Using Standard Rewards')
plt.show()


#--PPO LSTM-COMPARISON- squarepeg--------------------


plt.figure(figsize=(14, 5))
plt.subplot(1, 2, 1)
#plt.plot(rewardlist_squarepeg_standard_rewards,label='Rewards')
plt.plot(rewardlist_rollingavg_squarepeg_standard_rewards,label='Square Peg DQN,Standard Rewards')
#plt.plot(rewardlist_squarepeg_squarepeg_GRU_rewards,label='Rewards')
plt.plot(rewardlist_rollingavg_squarepeg_GRU_rewards,label='Square Peg DQN,GRU Rewards')
plt.plot(rewardlist_rollingavg_PPO_LSTM_lr001_squarepeg_standard_rewards,label='Square Peg,PPO w/ LSTM Layers Lr=0.001  Std. Rwds')
plt.plot(rewardlist_rollingavg_PPO_LSTM_lr0001_squarepeg_standard_rewards,label='Square Peg,PPO w/ LSTM Layers Lr=0.0001  Std. Rwds')
plt.legend(loc='lower right')
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.title('Square Peg DQN vs PPO with LSTM \n Layers 50-Episode \n Rolling Averages of End-Of-Episode Rewards')


plt.subplot(1, 2, 2)
#plt.plot(zposition_squarepeg_standard_rewards,label='End-Of-Episode Z-axis Position')
plt.plot(zposition_rollingavg_squarepeg_standard_rewards,label='Square Peg, DQN with Standard Rewards')
#plt.plot(zposition_squarepeg_squarepeg_GRU_rewards,label='End-Of-Episode Z-axis Position')
plt.plot(zposition_rollingavg_squarepeg_GRU_rewards,label='Square Peg, DQN with GRU Rewards')
plt.plot(zposition_rollingavg_PPO_LSTM_lr001_squarepeg_standard_rewards,label='Square Peg,PPO w/ LSTM Layers Lr=0.001 Std. Rwds.')
plt.plot(zposition_rollingavg_PPO_LSTM_lr0001_squarepeg_standard_rewards,label='Square Peg,PPO w/ LSTM Layers Lr=0.0001 Std. Rwds.')

plt.legend(loc='upper right')
plt.xlabel('Episode')
plt.ylabel('Z axis position (mm)')
plt.title('Square Peg DQN vs PPO with LSTM Layers \n  50-Episode Rolling Averages of End-Of-Episode Z-Axis Position')
plt.show()

# %%
rewardlabel1='Rewards'
rewardlabel2='Rewards, 50-Ep. Rolling Avg.'

zlabel1='Z-axis Position'
zlabel2='Z-axis Position, 50-Ep. Rolling Avg.'

plt.figure(figsize=(14, 5))
plt.subplot(1, 2, 1)
plt.scatter([*range(len(rewardlist_roundpeg_standard_rewards))],rewardlist_roundpeg_standard_rewards,label=rewardlabel1,color="orange")
#plt.plot(rewardlist_roundpeg_standard_rewards,label=rewardlabel1)
plt.plot(rewardlist_rollingavg_roundpeg_standard_rewards,label=rewardlabel2, linewidth=3)
plt.legend(loc='lower right')
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.title('Round Peg DQN End-of-Episode Rewards \n During Training Using Standard Rewards')

plt.subplot(1, 2, 2)
plt.scatter([*range(len(zposition_roundpeg_standard_rewards))],zposition_roundpeg_standard_rewards,label=zlabel1,color="orange")
plt.plot(zposition_rollingavg_roundpeg_standard_rewards,label=zlabel2, linewidth=3)
plt.legend(loc='upper right')
plt.xlabel('Episode')
plt.ylabel('Z axis position (mm)')
plt.title('Round Peg DQN Final Wrist Z-Axis Positions Per \n Episode During Training Using Standard Rewards')
plt.show()


plt.figure(figsize=(14, 5))
plt.subplot(1, 2, 1)
plt.scatter([*range(len(zposition_roundpeg_standard_rewards))],rewardlist_roundpeg_GRU_rewards,label=rewardlabel1,color="orange")
plt.plot(rewardlist_rollingavg_roundpeg_GRU_rewards,label=rewardlabel2, linewidth=3)
plt.legend(loc='lower right')
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.title('Round Peg DQN End-of-Episode Rewards \n During Training Using GRU Rewards')

plt.subplot(1, 2, 2)
plt.scatter([*range(len(zposition_roundpeg_standard_rewards))],zposition_roundpeg_GRU_rewards,label=zlabel1,color="orange")
plt.plot(zposition_rollingavg_roundpeg_GRU_rewards,label=zlabel2, linewidth=3)
plt.legend(loc='upper right')
plt.xlabel('Episode')
plt.ylabel('Z axis position (mm)')
plt.title('Round Peg DQN Final Wrist Z-Axis Positions Per \n Episode During Training Using GRU Rewards')
plt.show()

# Overlaid Square peg Results:

plt.figure(figsize=(14, 5))
plt.subplot(1, 2, 1)
#plt.plot(rewardlist_squarepeg_standard_rewards,label='Rewards')
plt.plot(rewardlist_rollingavg_roundpeg_standard_rewards,label='Standard Rewards')
#plt.plot(rewardlist_squarepeg_squarepeg_GRU_rewards,label='Rewards')
plt.plot(rewardlist_rollingavg_roundpeg_GRU_rewards,label='GRU Rewards')
plt.legend(loc='lower right')
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.title('Round Peg DQN 50-Episode Rolling Averages of End-of-Episode Rewards')

plt.subplot(1, 2, 2)
#plt.plot(zposition_squarepeg_standard_rewards,label='End-Of-Episode Z-axis Position')
plt.plot(zposition_rollingavg_roundpeg_standard_rewards,label='Standard Rewards')
#plt.plot(zposition_squarepeg_squarepeg_GRU_rewards,label='End-Of-Episode Z-axis Position')
plt.plot(zposition_rollingavg_roundpeg_GRU_rewards,label='GRU Rewards')

plt.legend(loc='upper right')
plt.xlabel('Episode')
plt.ylabel('Z axis position (mm)')
plt.title('Round Peg DQN 50-Episode Rolling Averages of \n End-Of-Episode Z-Axis Position')
plt.show()


#Square peg---------------------------------


plt.figure(figsize=(14, 5))
plt.subplot(1, 2, 1)
plt.scatter([*range(len(rewardlist_squarepeg_standard_rewards))],rewardlist_squarepeg_standard_rewards,label=rewardlabel1
            ,color="orange")
plt.plot(rewardlist_rollingavg_squarepeg_standard_rewards,label=rewardlabel2, linewidth=3)
plt.legend(loc='lower right')
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.title('Square Peg DQN End-of-Episode Rewards \n During Training Using Standard Rewards')

plt.subplot(1, 2, 2)
plt.scatter([*range(len(zposition_squarepeg_standard_rewards))],zposition_squarepeg_standard_rewards,label=zlabel1,color="orange")
plt.plot(zposition_rollingavg_squarepeg_standard_rewards,label=zlabel2, linewidth=3)
plt.legend(loc='upper right')
plt.xlabel('Episode')
plt.ylabel('Z axis position (mm)')
plt.title('Square Peg DQN Final Z-Axis Positions Per \n Episode During Training Using Standard Rewards')
plt.show()



plt.figure(figsize=(14, 5))
plt.subplot(1, 2, 1)
plt.scatter([*range(len(rewardlist_squarepeg_squarepeg_GRU_rewards))],rewardlist_squarepeg_squarepeg_GRU_rewards,label=rewardlabel1,color="orange")
plt.plot(rewardlist_rollingavg_squarepeg_GRU_rewards,label=rewardlabel2, linewidth=3)
plt.ylim([-0.05, 1.05])
plt.legend(loc='lower right')
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.title('Square Peg DQN End-of-Episode Rewards \n During Training Using GRU Rewards')

plt.subplot(1, 2, 2)
plt.scatter([*range(len(zposition_squarepeg_squarepeg_GRU_rewards))],
            zposition_squarepeg_squarepeg_GRU_rewards,label=zlabel1,color="orange")
plt.plot(zposition_rollingavg_squarepeg_GRU_rewards,label=zlabel2, linewidth=3)
plt.legend(loc='upper right')
plt.xlabel('Episode')
plt.ylabel('Z axis position (mm)')
plt.title('Square Peg DQN Final Z-Axis Positions Per \n Episode During Training Using GRU Rewards')
plt.show()


# Overlaid Square peg Results:

plt.figure(figsize=(14, 5))
plt.subplot(1, 2, 1)
#plt.plot(rewardlist_squarepeg_standard_rewards,label='Rewards')
plt.plot(rewardlist_rollingavg_squarepeg_standard_rewards,label='Standard Rewards')
#plt.plot(rewardlist_squarepeg_squarepeg_GRU_rewards,label='Rewards')
plt.plot(rewardlist_rollingavg_squarepeg_GRU_rewards,label='GRU Rewards')

plt.legend(loc='lower right')
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.title('Square Peg DQN 50-Episode Rolling Averages of End-of-Episode Rewards')

plt.subplot(1, 2, 2)
#plt.plot(zposition_squarepeg_standard_rewards,label='End-Of-Episode Z-axis Position')
plt.plot(zposition_rollingavg_squarepeg_standard_rewards,label='Standard Rewards')
#plt.plot(zposition_squarepeg_squarepeg_GRU_rewards,label='End-Of-Episode Z-axis Position')
plt.plot(zposition_rollingavg_squarepeg_GRU_rewards,label='GRU Rewards')

plt.legend(loc='upper right')
plt.xlabel('Episode')
plt.ylabel('Z axis position (mm)')
plt.title('Square Peg DQN 50-Episode Rolling Averages of \n End-Of-Episode Z-Axis Position')
plt.show()



# Overlaid All rolling averages

plt.figure(figsize=(14, 5))
plt.subplot(1, 2, 1)
#plt.plot(rewardlist_squarepeg_standard_rewards,label='Rewards')
plt.plot(rewardlist_rollingavg_roundpeg_standard_rewards,label='Round Peg,Standard Rewards')
#plt.plot(rewardlist_squarepeg_squarepeg_GRU_rewards,label='Rewards')
plt.plot(rewardlist_rollingavg_roundpeg_GRU_rewards,label='Round Peg,GRU Rewards')
plt.plot(rewardlist_rollingavg_squarepeg_standard_rewards,label='Square Peg,Standard Rewards')
#plt.plot(rewardlist_squarepeg_squarepeg_GRU_rewards,label='Rewards')
plt.plot(rewardlist_rollingavg_squarepeg_GRU_rewards,label='Square Peg,GRU Rewards')
plt.legend(loc='lower right')
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.title('Round Peg and Square Peg DQN 50-Episode \n Rolling Averages of End-of-Episode Rewards')


plt.subplot(1, 2, 2)
#plt.plot(zposition_squarepeg_standard_rewards,label='End-Of-Episode Z-axis Position')
plt.plot(zposition_rollingavg_roundpeg_standard_rewards,label='Round Peg,Standard Rewards')
#plt.plot(zposition_squarepeg_squarepeg_GRU_rewards,label='End-Of-Episode Z-axis Position')
plt.plot(zposition_rollingavg_roundpeg_GRU_rewards,label='Round Peg,GRU Rewards')
plt.plot(zposition_rollingavg_squarepeg_standard_rewards,label='Square Peg,Standard Rewards')
#plt.plot(zposition_squarepeg_squarepeg_GRU_rewards,label='End-Of-Episode Z-axis Position')
plt.plot(zposition_rollingavg_squarepeg_GRU_rewards,label='Square Peg,GRU Rewards')

plt.legend(loc='center right')
plt.xlabel('Episode')
plt.ylabel('Z axis position (mm)')
plt.title('Round Peg and Square Peg DQN 50-Episode Rolling \n Averages of  End-Of-Episode Z-Axis Position')
plt.show()

#--PPO LSTM---------------------

plt.figure(figsize=(14, 5))
plt.subplot(1, 2, 1)
#plt.scatter([*range(len(rewardlist_roundpeg_standard_rewards))],rewardlist_roundpeg_standard_rewards,label=rewardlabel1)
plt.scatter([*range(len(rewardlist_roundpeg_PPO_LSTM_lr001_standard_rewards))],
            rewardlist_roundpeg_PPO_LSTM_lr001_standard_rewards,label=rewardlabel1,color="orange")
plt.plot(rewardlist_rollingavg_PPO_LSTM_lr001_roundpeg_standard_rewards,label=rewardlabel2, linewidth=3)
plt.legend(loc='lower right')
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.title('Round Peg PPO with LSTM Lr=0.001 \n Layers End-Of-Episode Rewards \n During Training Using Standard Rewards')

plt.subplot(1, 2, 2)
plt.scatter([*range(len(zposition_roundpeg_PPO_LSTM_lr001_standard_rewards))],
            zposition_roundpeg_PPO_LSTM_lr001_standard_rewards,label=zlabel1,color="orange")
plt.plot(zposition_rollingavg_PPO_LSTM_lr001_roundpeg_standard_rewards,label=zlabel2, linewidth=3)
plt.legend(loc='upper right')
plt.xlabel('Episode')
plt.ylabel('Z axis position (mm)')
plt.title('Round Peg PPO with LSTM Layers Lr=0.001 \n Final Wrist Z-Axis Positions Per Episode During \n Training Using Standard Rewards')
plt.show()


plt.figure(figsize=(14, 5))
plt.subplot(1, 2, 1)
#plt.scatter([*range(len(rewardlist_roundpeg_standard_rewards))],rewardlist_roundpeg_standard_rewards,label=rewardlabel1)
plt.scatter([*range(len(rewardlist_roundpeg_PPO_LSTM_lr0001_standard_rewards))],
            rewardlist_roundpeg_PPO_LSTM_lr0001_standard_rewards,label=rewardlabel1,color="orange")
plt.plot(rewardlist_rollingavg_PPO_LSTM_lr0001_roundpeg_standard_rewards,label=rewardlabel2, linewidth=3)
plt.legend(loc='lower right')
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.title('Round Peg PPO with LSTM Layers Lr=0.0001 \n End-Of-Episode Rewards  \n During Training Using Standard Rewards')

plt.subplot(1, 2, 2)
plt.scatter([*range(len(zposition_roundpeg_PPO_LSTM_lr0001_standard_rewards))],
            zposition_roundpeg_PPO_LSTM_lr0001_standard_rewards,label=zlabel1,color="orange")
plt.plot(zposition_rollingavg_PPO_LSTM_lr0001_roundpeg_standard_rewards,label=zlabel2, linewidth=3)
plt.legend(loc='upper right')
plt.xlabel('Episode')
plt.ylabel('Z axis position (mm)')
plt.title('Round Peg PPO with LSTM Layers Lr=0.0001 \n Final Wrist Z-Axis Positions Per  Episode \n During Training Using Standard Rewards')
plt.show()


#--PPO LSTM-COMPARISON roundpeg--------------------


plt.figure(figsize=(14, 5))
plt.subplot(1, 2, 1)
#plt.plot(rewardlist_squarepeg_standard_rewards,label='Rewards')
plt.plot(rewardlist_rollingavg_roundpeg_standard_rewards,label='Round Peg DQN,Standard Rewards')
#plt.plot(rewardlist_squarepeg_squarepeg_GRU_rewards,label='Rewards')
plt.plot(rewardlist_rollingavg_roundpeg_GRU_rewards,label='Round Peg DQN,GRU Rewards')
plt.plot(rewardlist_rollingavg_PPO_LSTM_lr001_roundpeg_standard_rewards,label='Round Peg,PPO w/ LSTM Layers Lr=0.001  Std. Rwds')
plt.plot(rewardlist_rollingavg_PPO_LSTM_lr0001_roundpeg_standard_rewards,label='Round Peg,PPO w/ LSTM Layers Lr=0.0001  Std. Rwds')
plt.legend(loc='lower right')
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.title('Round Peg DQN vs PPO with LSTM Layers 50-Episode \n Rolling Averages of End-Of-Episode Rewards')


plt.subplot(1, 2, 2)
#plt.plot(zposition_squarepeg_standard_rewards,label='End-Of-Episode Z-axis Position')
plt.plot(zposition_rollingavg_roundpeg_standard_rewards,label='Round Peg, DQN with Standard Rewards')
#plt.plot(zposition_squarepeg_squarepeg_GRU_rewards,label='End-Of-Episode Z-axis Position')
plt.plot(zposition_rollingavg_roundpeg_GRU_rewards,label='Round Peg, DQN with GRU Rewards')
plt.plot(zposition_rollingavg_PPO_LSTM_lr001_roundpeg_standard_rewards,label='Round Peg,PPO w/ LSTM Layers Lr=0.001 Std. Rwds.')
plt.plot(zposition_rollingavg_PPO_LSTM_lr0001_roundpeg_standard_rewards,label='Round Peg,PPO w/ LSTM Layers Lr=0.0001 Std. Rwds.')

plt.legend(loc='upper right')
plt.xlabel('Episode')
plt.ylabel('Z axis position (mm)')
plt.title('Round Peg DQN vs PPO with LSTM Layers 50-Episode Rolling \n Averages of End-Of-Episode Z-Axis Position')
plt.show()

#--PPO LSTM- squarepeg---------------------

plt.figure(figsize=(14, 5))
plt.subplot(1, 2, 1)
#plt.scatter([*range(len(rewardlist_roundpeg_standard_rewards))],rewardlist_roundpeg_standard_rewards,label=rewardlabel1)
plt.scatter([*range(len(rewardlist_squarepeg_PPO_LSTM_lr001_standard_rewards))],rewardlist_squarepeg_PPO_LSTM_lr001_standard_rewards,label=rewardlabel1,color="orange")
plt.plot(rewardlist_rollingavg_PPO_LSTM_lr001_squarepeg_standard_rewards,label=rewardlabel2, linewidth=3)
plt.legend(loc='lower right')
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.title('Square Peg PPO with LSTM  Layers Lr=0.001 \n End-Of-Episode Rewards During Training Using Standard Rewards')

plt.subplot(1, 2, 2)
plt.scatter([*range(len(zposition_squarepeg_PPO_LSTM_lr001_standard_rewards))],zposition_squarepeg_PPO_LSTM_lr001_standard_rewards,label=zlabel1,color="orange")
plt.plot(zposition_rollingavg_PPO_LSTM_lr001_squarepeg_standard_rewards,label=zlabel2, linewidth=3)
plt.legend(loc='upper right')
plt.xlabel('Episode')
plt.ylabel('Z axis position (mm)')
plt.title('Square Peg PPO with LSTM Layers Lr=0.001 \n Final Wrist Z-Axis Positions Per \n Episode During Training Using Standard Rewards')
plt.show()


plt.figure(figsize=(14, 5))
plt.subplot(1, 2, 1)
#plt.scatter([*range(len(rewardlist_roundpeg_standard_rewards))],rewardlist_roundpeg_standard_rewards,label=rewardlabel1)
plt.scatter([*range(len(rewardlist_squarepeg_PPO_LSTM_lr0001_standard_rewards))],rewardlist_squarepeg_PPO_LSTM_lr0001_standard_rewards,label=rewardlabel1,color="orange")
plt.plot(rewardlist_rollingavg_PPO_LSTM_lr0001_squarepeg_standard_rewards,label=rewardlabel2, linewidth=3)
plt.legend(loc='lower right')
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.title('Square Peg PPO with LSTM Layers Lr=0.0001 \n  End-Of-Episode Rewards During Training Using Standard Rewards')

plt.subplot(1, 2, 2)
plt.scatter([*range(len(zposition_squarepeg_PPO_LSTM_lr0001_standard_rewards))],zposition_squarepeg_PPO_LSTM_lr0001_standard_rewards,label=zlabel1,color="orange")
plt.plot(zposition_rollingavg_PPO_LSTM_lr0001_squarepeg_standard_rewards,label=zlabel2, linewidth=3)
plt.legend(loc='upper right')
plt.xlabel('Episode')
plt.ylabel('Z axis position (mm)')
plt.title('Square Peg PPO with LSTM Layers Lr=0.0001 \n Final Wrist Z-Axis Positions Per \n Episode During Training Using Standard Rewards')
plt.show()


#--PPO LSTM-COMPARISON- squarepeg--------------------


plt.figure(figsize=(14, 5))
plt.subplot(1, 2, 1)
#plt.plot(rewardlist_squarepeg_standard_rewards,label='Rewards')
plt.plot(rewardlist_rollingavg_squarepeg_standard_rewards,label='Square Peg DQN,Standard Rewards')
#plt.plot(rewardlist_squarepeg_squarepeg_GRU_rewards,label='Rewards')
plt.plot(rewardlist_rollingavg_squarepeg_GRU_rewards,label='Square Peg DQN,GRU Rewards')
plt.plot(rewardlist_rollingavg_PPO_LSTM_lr001_squarepeg_standard_rewards,label='Square Peg,PPO w/ LSTM Layers Lr=0.001  Std. Rwds')
plt.plot(rewardlist_rollingavg_PPO_LSTM_lr0001_squarepeg_standard_rewards,label='Square Peg,PPO w/ LSTM Layers Lr=0.0001  Std. Rwds')
plt.legend(loc='lower right')
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.title('Square Peg DQN vs PPO with LSTM Layers \n 50-Episode Rolling Averages of End-Of-Episode Rewards')


plt.subplot(1, 2, 2)
#plt.plot(zposition_squarepeg_standard_rewards,label='End-Of-Episode Z-axis Position')
plt.plot(zposition_rollingavg_squarepeg_standard_rewards,label='Square Peg, DQN with Standard Rewards')
#plt.plot(zposition_squarepeg_squarepeg_GRU_rewards,label='End-Of-Episode Z-axis Position')
plt.plot(zposition_rollingavg_squarepeg_GRU_rewards,label='Square Peg, DQN with GRU Rewards')
plt.plot(zposition_rollingavg_PPO_LSTM_lr001_squarepeg_standard_rewards,label='Square Peg,PPO w/ LSTM Layers Lr=0.001 Std. Rwds.')
plt.plot(zposition_rollingavg_PPO_LSTM_lr0001_squarepeg_standard_rewards,label='Square Peg,PPO w/ LSTM Layers Lr=0.0001 Std. Rwds.')

plt.legend(loc='upper right')
plt.xlabel('Episode')
plt.ylabel('Z axis position (mm)')
plt.title('Square Peg DQN vs PPO with LSTM Layers \n  50-Episode Rolling Averages of End-Of-Episode Z-Axis Position')
plt.show()

# %%
#--PPO LSTM-COMPARISON roundpeg--------------------


plt.figure(figsize=(14, 5))
plt.subplot(1, 2, 1)
#plt.plot(rewardlist_squarepeg_standard_rewards,label='Rewards')
plt.plot(rewardlist_rollingavg_roundpeg_standard_rewards,label='Round Peg DQN,Standard Rewards')
#plt.plot(rewardlist_squarepeg_squarepeg_GRU_rewards,label='Rewards')
plt.plot(rewardlist_rollingavg_roundpeg_GRU_rewards,label='Round Peg DQN,GRU Rewards')
plt.plot(rewardlist_rollingavg_PPO_LSTM_lr001_roundpeg_standard_rewards,label='Round Peg,PPO w/ LSTM Layers Lr=0.001  Std. Rwds')
plt.plot(rewardlist_rollingavg_PPO_LSTM_lr0001_roundpeg_standard_rewards,label='Round Peg,PPO w/ LSTM Layers Lr=0.0001  Std. Rwds')
plt.legend(loc='lower right')
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.title('Round Peg DQN vs PPO with LSTM Layers 50-Episode \n Rolling Averages of End-Of-Episode Rewards')


plt.subplot(1, 2, 2)
#plt.plot(zposition_squarepeg_standard_rewards,label='End-Of-Episode Z-axis Position')
plt.plot(zposition_rollingavg_roundpeg_standard_rewards,label='Round Peg, DQN with Standard Rewards')
#plt.plot(zposition_squarepeg_squarepeg_GRU_rewards,label='End-Of-Episode Z-axis Position')
plt.plot(zposition_rollingavg_roundpeg_GRU_rewards,label='Round Peg, DQN with GRU Rewards')
plt.plot(zposition_rollingavg_PPO_LSTM_lr001_roundpeg_standard_rewards,label='Round Peg,PPO w/ LSTM Layers Lr=0.001 Std. Rwds.')
plt.plot(zposition_rollingavg_PPO_LSTM_lr0001_roundpeg_standard_rewards,label='Round Peg,PPO w/ LSTM Layers Lr=0.0001 Std. Rwds.')

plt.legend(loc='upper right')
plt.xlabel('Episode')
plt.ylabel('Z axis position (mm)')
plt.title('Round Peg DQN vs PPO with LSTM Layers 50-Episode Rolling \n Averages of End-Of-Episode Z-Axis Position')
plt.show()

#--PPO LSTM-COMPARISON- squarepeg--------------------


plt.figure(figsize=(14, 5))
plt.subplot(1, 2, 1)
#plt.plot(rewardlist_squarepeg_standard_rewards,label='Rewards')
plt.plot(rewardlist_rollingavg_squarepeg_standard_rewards,label='Square Peg DQN,Standard Rewards')
#plt.plot(rewardlist_squarepeg_squarepeg_GRU_rewards,label='Rewards')
plt.plot(rewardlist_rollingavg_squarepeg_GRU_rewards,label='Square Peg DQN,GRU Rewards')
plt.plot(rewardlist_rollingavg_PPO_LSTM_lr001_squarepeg_standard_rewards,label='Square Peg,PPO w/ LSTM Layers Lr=0.001  Std. Rwds')
plt.plot(rewardlist_rollingavg_PPO_LSTM_lr0001_squarepeg_standard_rewards,label='Square Peg,PPO w/ LSTM Layers Lr=0.0001  Std. Rwds')
plt.legend(loc='lower right')
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.title('Square Peg DQN vs PPO with LSTM Layers \n 50-Episode Rolling Averages of End-Of-Episode Rewards')


plt.subplot(1, 2, 2)
#plt.plot(zposition_squarepeg_standard_rewards,label='End-Of-Episode Z-axis Position')
plt.plot(zposition_rollingavg_squarepeg_standard_rewards,label='Square Peg, DQN with Standard Rewards')
#plt.plot(zposition_squarepeg_squarepeg_GRU_rewards,label='End-Of-Episode Z-axis Position')
plt.plot(zposition_rollingavg_squarepeg_GRU_rewards,label='Square Peg, DQN with GRU Rewards')
plt.plot(zposition_rollingavg_PPO_LSTM_lr001_squarepeg_standard_rewards,label='Square Peg,PPO w/ LSTM Layers Lr=0.001 Std. Rwds.')
plt.plot(zposition_rollingavg_PPO_LSTM_lr0001_squarepeg_standard_rewards,label='Square Peg,PPO w/ LSTM Layers Lr=0.0001 Std. Rwds.')

plt.legend(loc='upper right')
plt.xlabel('Episode')
plt.ylabel('Z axis position (mm)')
plt.title('Square Peg DQN vs PPO with LSTM Layers \n  50-Episode Rolling Averages of End-Of-Episode Z-Axis Position')
plt.show()
