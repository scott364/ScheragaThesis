# %%
import gym

from baselines import deepq


def callback(lcl, _glb):
    # stop training if reward exceeds 199
    is_solved = lcl['t'] > 100 and sum(lcl['episode_rewards'][-101:-1]) / 100 >= 199
    return is_solved


def main():
    env = gym.make("CartPole-v0")
    act = deepq.learn(
        env,
        network='mlp',
        lr=1e-3,
        total_timesteps=100000,
        buffer_size=50000,
        exploration_fraction=0.1,
        exploration_final_eps=0.02,
        print_freq=10,
        callback=callback
    )
    print("Saving model to cartpole_model.pkl")
    act.save("cartpole_model.pkl")


if __name__ == '__main__':
    main()
# Out:
# /home/scott/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/scott/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/scott/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/scott/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/scott/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/scott/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/scott/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/scott/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/scott/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/scott/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/scott/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/scott/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# WARNING:tensorflow:From /home/scott/baselines/baselines/common/tf_util.py:53: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /home/scott/baselines/baselines/common/tf_util.py:63: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /home/scott/baselines/baselines/common/tf_util.py:70: The name tf.InteractiveSession is deprecated. Please use tf.compat.v1.InteractiveSession instead.
#
# WARNING:tensorflow:From /home/scott/baselines/baselines/common/misc_util.py:58: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
# /home/scott/.local/lib/python3.6/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# WARNING:tensorflow:From /home/scott/baselines/baselines/deepq/deepq.py:205: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /home/scott/baselines/baselines/deepq/build_graph.py:176: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /home/scott/baselines/baselines/common/input.py:57: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /home/scott/baselines/baselines/common/models.py:94: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From /home/scott/baselines/baselines/deepq/build_graph.py:189: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Logging to /tmp/openai-2021-02-24-09-53-20-380426
# --------------------------------------
# | % time spent exploring  | 97       |
# | episodes                | 10       |
# | mean 100 episode reward | 30.8     |
# | steps                   | 276      |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 95       |
# | episodes                | 20       |
# | mean 100 episode reward | 25.8     |
# | steps                   | 490      |
# --------------------------------------
# /home/scott/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/scott/.local/lib/python3.6/site-packages/numpy/core/_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# --------------------------------------
# | % time spent exploring  | 93       |
# | episodes                | 30       |
# | mean 100 episode reward | 24.5     |
# | steps                   | 709      |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 91       |
# | episodes                | 40       |
# | mean 100 episode reward | 21.8     |
# | steps                   | 851      |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 89       |
# | episodes                | 50       |
# | mean 100 episode reward | 21.5     |
# | steps                   | 1.05e+03 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 87       |
# | episodes                | 60       |
# | mean 100 episode reward | 22.4     |
# | steps                   | 1.32e+03 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 84       |
# | episodes                | 70       |
# | mean 100 episode reward | 23.4     |
# | steps                   | 1.62e+03 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 80       |
# | episodes                | 80       |
# | mean 100 episode reward | 24.9     |
# | steps                   | 1.97e+03 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 78       |
# | episodes                | 90       |
# | mean 100 episode reward | 24.6     |
# | steps                   | 2.19e+03 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 75       |
# | episodes                | 100      |
# | mean 100 episode reward | 24.8     |
# | steps                   | 2.46e+03 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 73       |
# | episodes                | 110      |
# | mean 100 episode reward | 24.7     |
# | steps                   | 2.75e+03 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 70       |
# | episodes                | 120      |
# | mean 100 episode reward | 25.5     |
# | steps                   | 3.04e+03 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 66       |
# | episodes                | 130      |
# | mean 100 episode reward | 27.6     |
# | steps                   | 3.46e+03 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 61       |
# | episodes                | 140      |
# | mean 100 episode reward | 31.1     |
# | steps                   | 3.96e+03 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 55       |
# | episodes                | 150      |
# | mean 100 episode reward | 34.6     |
# | steps                   | 4.51e+03 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 48       |
# | episodes                | 160      |
# | mean 100 episode reward | 39       |
# | steps                   | 5.23e+03 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 40       |
# | episodes                | 170      |
# | mean 100 episode reward | 44.1     |
# | steps                   | 6.03e+03 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 38       |
# | episodes                | 180      |
# | mean 100 episode reward | 42.8     |
# | steps                   | 6.25e+03 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 35       |
# | episodes                | 190      |
# | mean 100 episode reward | 44.2     |
# | steps                   | 6.61e+03 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 29       |
# | episodes                | 200      |
# | mean 100 episode reward | 47.8     |
# | steps                   | 7.24e+03 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 23       |
# | episodes                | 210      |
# | mean 100 episode reward | 50.2     |
# | steps                   | 7.77e+03 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 17       |
# | episodes                | 220      |
# | mean 100 episode reward | 53.8     |
# | steps                   | 8.42e+03 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 14       |
# | episodes                | 230      |
# | mean 100 episode reward | 53.1     |
# | steps                   | 8.77e+03 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 7        |
# | episodes                | 240      |
# | mean 100 episode reward | 55.2     |
# | steps                   | 9.47e+03 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 4        |
# | episodes                | 250      |
# | mean 100 episode reward | 52.3     |
# | steps                   | 9.74e+03 |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 260      |
# | mean 100 episode reward | 47.2     |
# | steps                   | 9.94e+03 |
# --------------------------------------
# Saving model due to mean reward increase: None -> 46.4
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 270      |
# | mean 100 episode reward | 43.5     |
# | steps                   | 1.04e+04 |
# --------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-93cfdd421eab> in <module>
#      28
#      29 if __name__ == '__main__':
# ---> 30     main()
#
# <ipython-input-1-93cfdd421eab> in main()
#      21         exploration_final_eps=0.02,
#      22         print_freq=10,
# ---> 23         callback=callback
#      24     )
#      25     print("Saving model to cartpole_model.pkl")
#
# ~/baselines/baselines/deepq/deepq.py in learn(env, network, seed, lr, total_timesteps, buffer_size, exploration_fraction, exploration_final_eps, train_freq, batch_size, print_freq, checkpoint_freq, checkpoint_path, learning_starts, gamma, target_network_update_freq, prioritized_replay, prioritized_replay_alpha, prioritized_replay_beta0, prioritized_replay_beta_iters, prioritized_replay_eps, param_noise, callback, load_path, **network_kwargs)
#     276                 kwargs['update_param_noise_threshold'] = update_param_noise_threshold
#     277                 kwargs['update_param_noise_scale'] = True
# --> 278             action = act(np.array(obs)[None], update_eps=update_eps, **kwargs)[0]
#     279             env_action = action
#     280             reset = False
#
# ~/baselines/baselines/deepq/deepq.py in __call__(self, *args, **kwargs)
#      45
#      46     def __call__(self, *args, **kwargs):
# ---> 47         return self._act(*args, **kwargs)
#      48
#      49     def step(self, observation, **kwargs):
#
# ~/baselines/baselines/deepq/build_graph.py in act(ob, stochastic, update_eps)
#     196                          updates=[update_eps_expr])
#     197         def act(ob, stochastic=True, update_eps=-1):
# --> 198             return _act(ob, stochastic, update_eps)
#     199         return act
#     200
#
# ~/baselines/baselines/common/tf_util.py in <lambda>(*args, **kwargs)
#     177     else:
#     178         f = _Function(inputs, [outputs], updates, givens=givens)
# --> 179         return lambda *args, **kwargs: f(*args, **kwargs)[0]
#     180
#     181
#
# ~/baselines/baselines/common/tf_util.py in __call__(self, *args, **kwargs)
#     209         for inpt_name, value in kwargs.items():
#     210             self._feed_input(feed_dict, self.input_names[inpt_name], value)
# --> 211         results = get_session().run(self.outputs_update, feed_dict=feed_dict)[:-1]
#     212         return results
#     213
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     948     try:
#     949       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 950                          run_metadata_ptr)
#     951       if run_metadata:
#     952         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1164     # TODO(yuanbyu, keveman): Revisit whether we should just treat feeding
#    1165     # of a handle from a different device as an error.
# -> 1166     _ = self._update_with_movers(feed_dict_tensor, feed_map)
#    1167     final_fetches = fetch_handler.fetches()
#    1168     final_targets = fetch_handler.targets()
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/client/session.py in _update_with_movers(self, feed_dict, feed_map)
#    1403     handle_movers = []
#    1404     for feed_name, val in feed_map.items():
# -> 1405       mover = session_ops._get_handle_mover(self.graph, *val)
#    1406       if mover:
#    1407         handle_movers.append((feed_name, val[1], mover))
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/client/session.py in graph(self)
#     767   def graph(self):
#     768     """The graph that was launched in this session."""
# --> 769     return self._graph
#     770
#     771   @property
#
# KeyboardInterrupt:

# %%
def main():
    env = gym.make("CartPole-v0")
    act = deepq.learn(env, network='mlp', total_timesteps=0, load_path="cartpole_model.pkl")

    while True:
        obs, done = env.reset(), False
        episode_rew = 0
        while not done:
            env.render()
            obs, rew, done, _ = env.step(act(obs[None])[0])
            episode_rew += rew
        print("Episode reward", episode_rew)


if __name__ == '__main__':
    main()
# Out:
# /home/scott/.local/lib/python3.6/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-eb7d77c216d6> in <module>
#      14
#      15 if __name__ == '__main__':
# ---> 16     main()
#
# <ipython-input-2-eb7d77c216d6> in main()
#       1 def main():
#       2     env = gym.make("CartPole-v0")
# ----> 3     act = deepq.learn(env, network='mlp', total_timesteps=0, load_path="cartpole_model.pkl")
#       4
#       5     while True:
#
# ~/baselines/baselines/deepq/deepq.py in learn(env, network, seed, lr, total_timesteps, buffer_size, exploration_fraction, exploration_final_eps, train_freq, batch_size, print_freq, checkpoint_freq, checkpoint_path, learning_starts, gamma, target_network_update_freq, prioritized_replay, prioritized_replay_alpha, prioritized_replay_beta0, prioritized_replay_beta_iters, prioritized_replay_eps, param_noise, callback, load_path, **network_kwargs)
#     206         gamma=gamma,
#     207         grad_norm_clipping=10,
# --> 208         param_noise=param_noise
#     209     )
#     210
#
# ~/baselines/baselines/deepq/build_graph.py in build_train(make_obs_ph, q_func, num_actions, optimizer, grad_norm_clipping, gamma, double_q, scope, reuse, param_noise, param_noise_filter_func)
#     374             param_noise_filter_func=param_noise_filter_func)
#     375     else:
# --> 376         act_f = build_act(make_obs_ph, q_func, num_actions, scope=scope, reuse=reuse)
#     377
#     378     with tf.variable_scope(scope, reuse=reuse):
#
# ~/baselines/baselines/deepq/build_graph.py in build_act(make_obs_ph, q_func, num_actions, scope, reuse)
#     179         update_eps_ph = tf.placeholder(tf.float32, (), name="update_eps")
#     180
# --> 181         eps = tf.get_variable("eps", (), initializer=tf.constant_initializer(0))
#     182
#     183         q_values = q_func(observations_ph.get(), num_actions, scope="q_func")
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/ops/variable_scope.py in get_variable(name, shape, dtype, initializer, regularizer, trainable, collections, caching_device, partitioner, validate_shape, use_resource, custom_getter, constraint, synchronization, aggregation)
#    1494       constraint=constraint,
#    1495       synchronization=synchronization,
# -> 1496       aggregation=aggregation)
#    1497
#    1498
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/ops/variable_scope.py in get_variable(self, var_store, name, shape, dtype, initializer, regularizer, reuse, trainable, collections, caching_device, partitioner, validate_shape, use_resource, custom_getter, constraint, synchronization, aggregation)
#    1237           constraint=constraint,
#    1238           synchronization=synchronization,
# -> 1239           aggregation=aggregation)
#    1240
#    1241   def _get_partitioned_variable(self,
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/ops/variable_scope.py in get_variable(self, name, shape, dtype, initializer, regularizer, reuse, trainable, collections, caching_device, partitioner, validate_shape, use_resource, custom_getter, constraint, synchronization, aggregation)
#     560           constraint=constraint,
#     561           synchronization=synchronization,
# --> 562           aggregation=aggregation)
#     563
#     564   def _get_partitioned_variable(self,
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/ops/variable_scope.py in _true_getter(name, shape, dtype, initializer, regularizer, reuse, trainable, collections, caching_device, partitioner, validate_shape, use_resource, constraint, synchronization, aggregation)
#     512           constraint=constraint,
#     513           synchronization=synchronization,
# --> 514           aggregation=aggregation)
#     515
#     516     synchronization, aggregation, trainable = (
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/ops/variable_scope.py in _get_single_variable(self, name, shape, dtype, initializer, regularizer, partition_info, reuse, trainable, collections, caching_device, validate_shape, use_resource, constraint, synchronization, aggregation)
#     862         tb = [x for x in tb if "tensorflow/python" not in x[0]][:5]
#     863         raise ValueError("%s Originally defined at:\n\n%s" %
# --> 864                          (err_msg, "".join(traceback.format_list(tb))))
#     865       found_var = self._vars[name]
#     866       if not shape.is_compatible_with(found_var.get_shape()):
#
# ValueError: Variable deepq/eps already exists, disallowed. Did you mean to set reuse=True or reuse=tf.AUTO_REUSE in VarScope? Originally defined at:
#
#   File "/home/scott/baselines/baselines/deepq/build_graph.py", line 181, in build_act
#     eps = tf.get_variable("eps", (), initializer=tf.constant_initializer(0))
#   File "/home/scott/baselines/baselines/deepq/build_graph.py", line 376, in build_train
#     act_f = build_act(make_obs_ph, q_func, num_actions, scope=scope, reuse=reuse)
#   File "/home/scott/baselines/baselines/deepq/deepq.py", line 208, in learn
#     param_noise=param_noise
#   File "<ipython-input-1-93cfdd421eab>", line 23, in main
#     callback=callback
#   File "<ipython-input-1-93cfdd421eab>", line 30, in <module>
#     main()
